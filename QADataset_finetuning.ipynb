# %% [markdown]
# # QADataset

# %%
# %pip install langchain -q
# %pip install pymupdf -q
# %pip install langchain-community -q
# %pip install langchain-openai -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 56.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 24.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 61.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.5/409.5 kB 34.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 82.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.2 MB/s eta 0:00:00

# %%
import fitz
import json
import glob
import os
from langchain_core.pydantic_v1 import BaseModel, Field
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from langchain_openai import ChatOpenAI
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

from resource.config import api_key

# 텍스트 추출
def extract_text_pdf(pdf_path):
    """
    PDF 파일에서 텍스트를 추출합니다.
    """
    docs = fitz.open(pdf_path)
    elements = []
    for page in docs:
        text = page.get_text()
        elements.append({'text': text.strip()})
    docs.close()
    return elements

# 데이터 구조
class QAPair(BaseModel):
    question: str = Field(description='Question generated from the text')
    answer: str = Field(description='Answer related to the Question')

# 프롬프트 템플릿
prompt = PromptTemplate.from_template(
    '''context information is below. You are only aware of this context and nothing else.
    {context}
    -----------------------------
    Given this context, generate questions based on the below query.
    You are a healthcare professional in {domain}.
    Your task is to provide exactly **{num_questions}** questions for an upcoming questions.
    You are not to provide more or less than this number of questions.
    The questions should be diverse in nature across the document.
    The purpose of questions is to use the information provided to inform people of first aid knowledge.
    You must also provide the answer to each question. The answer should be based on the context information provided only.

    Restrict the questions to the context information provided only.
    QUESTION and ANSWER should be written in Korean. Response in JSON format which contains the 'question' and 'answer'.
    ANSWER should be a complete sentence.

    # Format:
    ```json
    {{
        'QUESTION': '화상을 입었을 때는 어떻게 해야하나요?',
        'ANSWER': '화상부위를 흐르는 찬물 속에 넣어 적어도 10분 동안 담그고, 상처부위는 깨끗하고 가능하면 멸균 처리된 거즈로 덮습니다.'
    }},
    {{
        'QUESTION': '벌에 쏘였을 경우에는 어떻게 하나요?',
        'ANSWER': '피부에 벌침이 남아있는 경우, 신용카드 등으로 밀어서 제거한 후 2차 감염 방지를 위해 비누와 물로 씻어줍니다.'
    }},
    {{
        'QUESTION': '골절 사고를 당했을 때는 어떤 응급처치를 해야하나요?',
        'ANSWER': '심한 골절일 경우 부러진 뼈가 신경, 혈관, 근육을 손상하거나 복잡 골절이 되게 하는 일이 없도록 가능하면 부상자를 옮기지 말고 사고 발생 현장에서 움직이지 않도록 합니다.'
    }}
    ```
'''
)

# langchain 및 출력 파서 설정
parser = JsonOutputParser(pydantic_object=QAPair)

chain = (
    prompt
    | ChatOpenAI(
        model='gpt-4o',
        temperature=0,
        streaming=True,
        callbacks=[StreamingStdOutCallbackHandler()],
        openai_api_key=api_key  # Replace with your API key
    )
    | parser
)

# QA 데이터 생성 및 저장
def create_qa_dataset_from_folder(folder_path, output_file):

    # 폴더 내 모든 PDF 파일 탐색
    pdf_files = glob.glob(os.path.join(folder_path, '*.pdf'))

    # QA 생성
    qa_pair = []
    for pdf_file in pdf_files:
        print(f"Processing file: {pdf_file}")
        elements = extract_text_pdf(pdf_file)

        for i, element in enumerate(elements):
            if element['text']:
                try:
                    qa_pair.append(
                        chain.invoke(
                            {'context': element['text'], 'domain': 'AI', 'num_questions': '3'}
                        )
                    )
                except Exception as e:
                    print(f"Error processing element in file {pdf_file}, page {i + 1}: {e}")

# 생성된 데이터 중간 출력
print("Generated QA Data:")


# 실행
if __name__ == '__main__':
    folder_path = '/content/drive/MyDrive/3rd project_pdf '  # PDF 파일이 저장된 폴더 경로
    output_file = 'qa_dataset.json'  # JSON 저장 파일 경로
    create_qa_dataset_from_folder(folder_path, output_file)  # 폴더 내 모든 PDF 파일을 처리

    # PDF 파일을 처리한 후
    pdf_files = glob.glob(os.path.join(folder_path, '*.pdf'))  # 폴더 내 PDF 파일 경로 리스트
    qa_pair = []

    for pdf_file in pdf_files:
        elements = extract_text_pdf(pdf_file)  # 각 PDF 파일에 대해 텍스트 추출

        # 각 페이지별 텍스트 처리 및 QA 생성
        for i, element in enumerate(elements):
            if element['text']:  # 텍스트가 존재하는 경우
                try:
                    qa_pair.append(
                        chain.invoke(
                            {'context': element['text'], 'domain': 'AI', 'num_questions': '3'}
                        )
                    )
                except Exception as e:
                    print(f'Error processing element {i+1} in file {pdf_file}: {e}')

    # 생성된 QA 데이터를 JSON 파일로 저장
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(qa_pair, f, ensure_ascii=False, indent=4)
    print(f"QA dataset saved to {output_file}")
# Out:
# Generated QA Data:
# Processing file: /content/drive/MyDrive/3rd project_pdf /[매뉴얼]_스포츠응급처치_매뉴얼.pdf
# ```json
# {
#     "QUESTION": "응급처치 매뉴얼이란 무엇인가요?",
#     "ANSWER": "응급처치 매뉴얼은 응급 상황에서 적절한 조치를 취할 수 있도록 안내하는 지침서입니다."
# },
# {
#     "QUESTION": "응급처치 매뉴얼의 주요 목적은 무엇인가요?",
#     "ANSWER": "응급처치 매뉴얼의 주요 목적은 응급 상황에서 신속하고 효과적인 대응을 통해 부상자의 상태를 안정시키고 추가적인 손상을 방지하는 것입니다."
# },
# {
#     "QUESTION": "응급처치 매뉴얼은 어떤 상황에서 사용되나요?",
#     "ANSWER": "응급처치 매뉴얼은 다양한 응급 상황에서 사용되며, 예를 들어 화상, 골절, 벌에 쏘임 등의 상황에서 적절한 응급처치를 제공하는 데 사용됩니다."
# }
# ``````json
# {
#     "QUESTION": "심정지 상황에서 심폐소생술은 어떻게 수행하나요?",
#     "ANSWER": "심정지 상황에서는 즉시 심폐소생술을 시작해야 하며, 가슴 압박과 인공호흡을 번갈아 가며 수행합니다."
# },
# {
#     "QUESTION": "골절 및 염좌가 발생했을 때 부목고정은 어떻게 하나요?",
#     "ANSWER": "골절 및 염좌가 발생했을 때는 부목을 사용하여 손상 부위를 고정시켜 추가적인 손상을 방지합니다."
# },
# {
#     "QUESTION": "출혈이 발생했을 때 지혈을 위해 어떤 조치를 취해야 하나요?",
#     "ANSWER": "출혈이 발생했을 때는 깨끗한 천이나 붕대로 상처 부위를 압박하여 지혈을 시도합니다."
# }
# ``````json
# {
#     "QUESTION": "열사병이 발생했을 때는 어떻게 해야 하나요?",
#     "ANSWER": "열사병이 발생했을 때는 즉시 시원한 장소로 이동시키고, 옷을 느슨하게 하며, 체온을 낮추기 위해 물을 뿌리거나 젖은 수건으로 몸을 닦아줍니다."
# },
# {
#     "QUESTION": "저체온증이 의심될 때는 어떤 조치를 취해야 하나요?",
#     "ANSWER": "저체온증이 의심될 때는 따뜻한 장소로 이동시키고, 젖은 옷을 제거한 후 담요로 몸을 감싸 체온을 유지하도록 합니다."
# },
# {
#     "QUESTION": "천식으로 인한 호흡곤란이 있을 때는 어떻게 해야 하나요?",
#     "ANSWER": "천식으로 인한 호흡곤란이 있을 때는 환자가 편안한 자세를 취하도록 하고, 처방된 흡입기를 사용하여 증상을 완화시킵니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "응급처치의 기본 원칙은 무엇인가요?",
#         "ANSWER": "응급처치의 기본 원칙은 환자의 상태를 신속하게 평가하고, 필요한 경우 즉시 응급처치를 제공하여 생명을 구하고 상태를 안정시키는 것입니다."
#     },
#     {
#         "QUESTION": "응급처치 시 가장 먼저 해야 할 일은 무엇인가요?",
#         "ANSWER": "응급처치 시 가장 먼저 해야 할 일은 주변의 안전을 확인하고, 환자의 의식과 호흡을 평가하는 것입니다."
#     },
#     {
#         "QUESTION": "응급처치 교육의 중요성은 무엇인가요?",
#         "ANSWER": "응급처치 교육은 비상 상황에서 적절한 대처를 통해 생명을 구하고 부상 정도를 최소화할 수 있도록 도와주는 중요한 지식과 기술을 제공합니다."
#     }
# ]
# ``````json
# [
#     {
#         "QUESTION": "스포츠 활동 중 응급상황이 발생했을 때 왜 신속하고 적절한 응급처치가 중요한가요?",
#         "ANSWER": "응급처치를 얼마나 신속하고 적절하게 실시하였는가에 따라 부상자의 삶과 죽음, 일시적 장애와 영구적인 손상이 결정되기 때문에 매우 중요합니다."
#     },
#     {
#         "QUESTION": "응급상황에서 119에 신고할 때 어떤 절차를 따라야 하나요?",
#         "ANSWER": "즉시 전화하고 필수 정보를 알리며, 질문에 대답하고 전화를 먼저 끊지 않으며 신고 후 지체없이 처치를 해야 합니다."
#     },
#     {
#         "QUESTION": "응급상황에서 현장조사 시 확인해야 할 사항은 무엇인가요?",
#         "ANSWER": "현장이 안전한지, 긴박한 위험이 있는지, 사고의 유형은 무엇인지, 환자의 수는 몇 명인지, 도움을 줄 사람이 있는지를 확인해야 합니다."
#     }
# ]
# ``````json
# [
#     {
#         "QUESTION": "스포츠 활동 중 응급상황이 발생했을 때 가장 먼저 해야 할 일은 무엇인가요?",
#         "ANSWER": "스포츠 활동 중 응급상황이 발생했을 때 가장 먼저 해야 할 일은 119에 신고하는 것입니다. 사고 발생 즉시 신고하여 구급대원이 현장에 빨리 도착할수록 환자의 예후에 긍정적인 영향을 미치게 됩니다."
#     },
#     {
#         "QUESTION": "응급상황에서 환자의 상태를 확인할 때 어떤 징후를 살펴봐야 하나요?",
#         "ANSWER": "응급상황에서 환자의 상태를 확인할 때는 환자가 의식이 있는지, 숨을 쉬는 것이 곤란한지, 가슴이나 목에 통증이 있는지, 이유 없이 땀을 흘리지는 않는지, 피부색이 창백하거나 푸르게 변하지는 않았는지를 확인해야 합니다."
#     },
#     {
#         "QUESTION": "응급처치를 할 때 환자의 분비물과 접촉하지 않기 위해 어떤 장비를 사용해야 하나요?",
#         "ANSWER": "응급처치를 할 때 환자의 분비물과 접촉하지 않기 위해 소독장갑이나 보호 장비를 사용해야 합니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "전봇대의 고유번호는 어떤 상황에서 유용하게 사용될 수 있나요?",
#     "ANSWER": "전봇대의 고유번호는 낯선 곳에서 자신의 위치를 파악할 때 유용하게 사용될 수 있습니다."
# },
# {
#     "QUESTION": "승강기 사고 발생 시 소방관이 위치를 파악하는 방법은 무엇인가요?",
#     "ANSWER": "승강기 사고 발생 시 소방관은 내부 층수 버튼 옆에 있는 승강기 고유번호와 QR 코드를 통해 위치를 파악할 수 있습니다."
# },
# {
#     "QUESTION": "승강기 고유번호는 어떤 상황에서 확인해야 하나요?",
#     "ANSWER": "승강기 고유번호는 승강기 사고 발생 시 확인해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "응급처치를 시작하기 전에 환자에게 어떤 절차를 따라야 하나요?",
#     "ANSWER": "응급처치를 시작하기 전에 환자에게 사전 동의를 구해야 하며, 이를 위해 자신의 이름, 신분 및 응급처치 교육경력을 밝히고 앞으로 행할 응급처치에 대한 설명을 해야 합니다."
# },
# {
#     "QUESTION": "환자가 의식이 없는 경우 응급처치를 어떻게 진행해야 하나요?",
#     "ANSWER": "환자가 의식이 없는 경우에는 주변 가족에게 동의를 구하거나 가족이 없을 경우 환자가 응급처치에 동의할 것이라는 가정 하에 묵시적 동의로 응급처치를 시행합니다."
# },
# {
#     "QUESTION": "골절이 발생했을 때 응급처치 방법은 무엇인가요?",
#     "ANSWER": "골절 시에는 부상부위를 부목으로 고정시켜 움직임을 최소화하는 방법을 사용합니다."
# }
# ``````json
# {
#     "QUESTION": "기도를 방해하거나 폐쇄를 일으킬 수 있는 손상에는 어떤 것들이 있나요?",
#     "ANSWER": "기도를 방해하거나 폐쇄를 일으킬 수 있는 손상에는 흡인성 손상, 흉곽 손상, 긴장성 기흉, 질식을 초래하거나 질식 상태에 있는 상악이나 안면의 손상이 있습니다."
# },
# {
#     "QUESTION": "즉각적인 지혈이 필요한 상황은 어떤 경우인가요?",
#     "ANSWER": "즉각적인 지혈이 필요한 상황은 즉각적 지혈을 요하는 모든 출혈이 발생한 경우입니다."
# },
# {
#     "QUESTION": "응급 처치 시 우선 순위는 어떻게 되나요?",
#     "ANSWER": "응급 처치 시 우선 순위는 즉각적인 처치를 요하는 환자와 긴급 수술을 요하는 환자가 1순위이며, 수술이 필요하지만 지연이 가능한 환자가 2순위입니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "선한 사마리아인법이란 무엇인가요?",
#         "ANSWER": "선한 사마리아인법은 고통 받는 사람을 기꺼이 도와주기 위하여, 즉 도덕적 의무를 이행하다가 예기치 않은 피해가 발생하더라도 고의나 중대한 과실이 없을 경우에는 민, 형사상 책임을 면제하는 것을 의미합니다."
#     },
#     {
#         "QUESTION": "선한 사마리아인법이 적용되기 위한 조건은 무엇인가요?",
#         "ANSWER": "선한 사마리아인법이 적용되기 위해서는 생명이 위급한 상황에서 행동을 하고, 올바른 신념에 따라 행동하며, 보상을 바라지 않고 행동하고, 악의에 찬 행위 또는 지나친 과실을 범하지 않아야 합니다."
#     },
#     {
#         "QUESTION": "응급의료종사자가 아닌 사람이 응급처치를 제공할 때 책임이 면제되는 경우는 언제인가요?",
#         "ANSWER": "응급의료종사자가 아닌 자가 응급처치를 제공하여 발생한 재산상 손해와 사상에 대하여 고의 또는 중대한 과실이 없는 경우 그 행위자는 민사 책임과 상해에 대한 형사 책임을 지지 아니하고 사망에 대한 형사 책임은 감면됩니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "심정지 상황에서는 어떤 응급처치를 해야 하나요?",
#     "ANSWER": "심정지 상황에서는 즉시 심폐소생술(CPR)을 시작하고, 가능한 빨리 자동 심장 충격기(AED)를 사용해야 합니다."
# },
# {
#     "QUESTION": "심정지 상황에서 자동 심장 충격기(AED)는 어떻게 사용하나요?",
#     "ANSWER": "자동 심장 충격기(AED)는 전원을 켜고, 음성 안내에 따라 패드를 환자의 가슴에 부착한 후, 지시에 따라 충격 버튼을 눌러 사용합니다."
# },
# {
#     "QUESTION": "심정지 상황에서 심폐소생술(CPR)은 어떻게 수행하나요?",
#     "ANSWER": "심폐소생술(CPR)은 환자의 가슴 중앙에 손을 겹쳐 놓고, 팔을 곧게 펴서 체중을 실어 분당 100~120회의 속도로 강하고 빠르게 압박합니다."
# }
# ``````json
# {
#     "QUESTION": "심정지 환자를 발견했을 때 가장 먼저 해야 할 일은 무엇인가요?",
#     "ANSWER": "심정지 환자를 발견하면 즉시 의료인에게 도움을 청해야 하며 심폐소생술을 실시해야 합니다."
# },
# {
#     "QUESTION": "심정지 전조 증상 중 하나로 나타날 수 있는 증상은 무엇인가요?",
#     "ANSWER": "심정지 전조 증상 중 하나로 가슴 가운데 왼쪽 또는 명치 끝에 쥐어짜는 듯한 통증이 일어날 수 있습니다."
# },
# {
#     "QUESTION": "심정지 시 심폐소생술이 중요한 이유는 무엇인가요?",
#     "ANSWER": "심정지 환자가 발견된 즉시 심폐소생술이 시행된 경우에는 심폐소생술이 시행되지 않은 경우에 비하여 일반적으로 생존율이 3배 정도 높기 때문입니다."
# }
# ``````json
# {
#     "QUESTION": "심폐소생술을 시작하기 전에 환자에게 어떤 조치를 취해야 하나요?",
#     "ANSWER": "환자의 반응을 확인하기 위해 어깨를 가볍게 두드리며 큰소리로 '괜찮으세요?'라고 물어보고, 특정인을 지목하여 119 신고를 요청해야 합니다."
# },
# {
#     "QUESTION": "심폐소생술 중 가슴 압박의 속도와 깊이는 어떻게 해야 하나요?",
#     "ANSWER": "가슴 압박의 깊이는 약 5cm로 하고, 분당 100~120회의 속도로 압박해야 합니다."
# },
# {
#     "QUESTION": "인공호흡을 할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "환자의 코를 잡아서 막고 입을 크게 벌려 환자의 입을 완전히 막은 후 가슴이 올라올 정도로 1초 동안 숨을 불어 넣어야 하며, 숨을 불어 넣을 때에는 환자의 가슴이 부풀어 오르는지 확인해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "자동심장충격기(AED)를 사용할 때 전원을 켜는 이유는 무엇인가요?",
#     "ANSWER": "자동심장충격기(AED)를 사용할 때 전원을 켜는 것은 기계를 작동시켜 심장리듬 분석과 심장충격을 시행할 수 있도록 하기 위함입니다."
# },
# {
#     "QUESTION": "자동심장충격기(AED) 사용 시 패드를 부착할 위치는 어디인가요?",
#     "ANSWER": "자동심장충격기(AED) 사용 시 패드는 하나는 오른쪽 빗장뼈 아래, 나머지 하나는 왼쪽 겨드랑이 아래에 위치하도록 부착합니다."
# },
# {
#     "QUESTION": "심장리듬 분석 중에 가슴압박을 멈추지 않는 이유는 무엇인가요?",
#     "ANSWER": "심장리듬 분석 중에도 가슴압박을 멈추지 않는 이유는 환자의 혈액 순환을 지속적으로 유지하여 뇌와 다른 중요한 장기에 산소를 공급하기 위함입니다."
# }
# ``````json
# {
#     "QUESTION": "자동심장충격기(AED)의 위치를 어떻게 찾을 수 있나요?",
#     "ANSWER": "위급상황 시에는 휴대폰 어플리케이션을 이용하여 자동심장충격기 위치를 찾을 수 있습니다. 보건복지부의 ‘응급의료정보제공’ 어플리케이션을 다운받은 후 ‘제세동기 찾기’ 메뉴를 통해 현 위치를 중심으로 자동심장충격기가 설치된 위치를 알 수 있습니다."
# },
# {
#     "QUESTION": "스포츠 활동 전에 자동심장충격기(AED)를 미리 확인해야 하는 이유는 무엇인가요?",
#     "ANSWER": "스포츠 활동 참여 전 자동심장충격기가 있는 곳을 미리 확인하여 응급상황 시 신속히 사용할 수 있도록 하기 위해서입니다."
# },
# {
#     "QUESTION": "응급의료정보제공 어플리케이션을 통해 제공되는 정보는 무엇인가요?",
#     "ANSWER": "응급의료정보제공 어플리케이션을 통해 자동심장충격기(AED)의 설치 위치를 알 수 있는 정보를 제공합니다."
# }
# ``````json
# {
#     "QUESTION": "근골격계 손상 시 응급처치는 어떻게 해야 하나요?",
#     "ANSWER": "근골격계 손상 시에는 부상 부위를 고정하고, 가능한 한 움직이지 않도록 하며, 즉시 의료기관을 방문하여 전문적인 치료를 받는 것이 중요합니다."
# },
# {
#     "QUESTION": "근골격계 손상 예방을 위해 어떤 조치를 취할 수 있나요?",
#     "ANSWER": "근골격계 손상을 예방하기 위해서는 규칙적인 운동과 올바른 자세를 유지하고, 무거운 물건을 들 때는 적절한 방법을 사용하는 것이 중요합니다."
# },
# {
#     "QUESTION": "근골격계 손상 후 회복을 돕기 위한 방법은 무엇인가요?",
#     "ANSWER": "근골격계 손상 후 회복을 돕기 위해서는 적절한 휴식과 재활 운동을 병행하며, 필요시 물리치료를 받는 것이 도움이 됩니다."
# }
# ``````json
# {
#     "QUESTION": "염좌가 발생했을 때 나타나는 증상은 무엇인가요?",
#     "ANSWER": "염좌가 발생한 부위는 붓고 빨개지며 통증이 생기고, 누르면 아프며 멍이 들기도 하고 관절이 경직되어 운동성이 감소합니다."
# },
# {
#     "QUESTION": "단순 골절과 복잡 골절의 차이점은 무엇인가요?",
#     "ANSWER": "단순 골절은 골절 부위가 붓거나 저리고 아프며 제한적으로 움직일 수 있는 반면, 복잡 골절은 부러진 뼈의 끝이 피부를 뚫고 나와 심한 출혈이 동반될 수 있습니다."
# },
# {
#     "QUESTION": "스포츠 상황에서 근골격계 손상이 발생했을 때 왜 적절한 처치가 중요한가요?",
#     "ANSWER": "근골격계 손상은 적절한 처치가 이루어지지 않으면 2차적인 손상을 가져올 수 있으며, 영구적인 손상이나 장애를 초래할 수 있기 때문에 정확히 파악하고 적절하게 대처해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "R.I.C.E. 응급처치에서 'Ice'는 어떤 역할을 하나요?",
#     "ANSWER": "R.I.C.E. 응급처치에서 'Ice'는 부종과 염증을 줄이면서 통증과 근육경련을 줄여주는 역할을 합니다."
# },
# {
#     "QUESTION": "골절이나 염좌 시 상처부위를 어떻게 해야 하나요?",
#     "ANSWER": "골절이나 염좌 시 상처부위는 되도록 움직이지 않도록 하고 경우에 따라 고정시켜야 합니다."
# },
# {
#     "QUESTION": "상처부위를 심장보다 높게 올리는 이유는 무엇인가요?",
#     "ANSWER": "상처부위를 심장보다 높게 올리면 다친 부위로 혈액이 덜 가게 되어 내부 출혈이 억제되고 부종이 줄어듭니다."
# }
# ``````json
# {
#     "QUESTION": "부상자를 운반해야 할 때 골절 부위의 2차 손상을 방지하기 위해 어떻게 해야 하나요?",
#     "ANSWER": "부상자를 운반해야 하는 경우 골절 부위가 2차 손상을 일으키는 것에 대비하여 반드시 부목을 댄 후 운반합니다."
# },
# {
#     "QUESTION": "부목을 사용할 수 없는 경우에는 어떻게 해야 하나요?",
#     "ANSWER": "부목을 댈 여유가 없을 때나 긴급히 옮겨야 할 경우에는 한 손으로 골절된 부위의 위쪽을, 다른 손으로 그 아래쪽을 보호하여 환자를 운반하도록 합니다."
# },
# {
#     "QUESTION": "전문 구조요원의 도움이 절대적으로 필요한 경우는 언제인가요?",
#     "ANSWER": "심한 근골격계 손상, 과다한 출혈, 머리, 목, 척추의 부상이나 다리 및 대퇴부 등의 골절로 환자 이송이 어려울 경우 전문 구조요원의 도움이 절대적으로 필요합니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "부목고정의 목적은 무엇인가요?",
#         "ANSWER": "부목고정의 목적은 상처 부위의 부러진 뼈에 의해 생길 수 있는 추가적인 손상을 방지하거나, 복잡 골절로 악화되는 것을 방지하고, 뼈에 의해 혈관이 압박되어 골절 원위부의 혈액순환이 차단되는 것을 방지하는 것입니다."
#     },
#     {
#         "QUESTION": "골절이 확실하지 않더라도 손상이 의심될 때는 어떻게 해야 하나요?",
#         "ANSWER": "골절이 확실하지 않더라도 손상이 의심될 때는 부목을 이용하여 고정해야 합니다."
#     },
#     {
#         "QUESTION": "부목을 댄 후에 주기적으로 확인해야 할 것은 무엇인가요?",
#         "ANSWER": "부목을 댄 후에도 골절 원위부에서 맥박, 감각, 운동기능을 주기적으로 확인해야 합니다."
#     }
# ]
# ``````json
# [
#     {
#         "QUESTION": "골절된 부위에 부목을 고정할 때 어떤 길이의 부목을 사용해야 하나요?",
#         "ANSWER": "부목은 골절된 뼈의 양쪽 관절 너머까지 걸칠 만큼 긴 것을 사용해야 합니다."
#     },
#     {
#         "QUESTION": "부목을 사용할 때 피부 손상을 방지하기 위해 어떤 조치를 취해야 하나요?",
#         "ANSWER": "부목 안쪽에 헝겊을 고여서 피부가 상하지 않도록 해야 합니다."
#     },
#     {
#         "QUESTION": "적당한 부목이 없을 경우 어떤 대체물을 사용할 수 있나요?",
#         "ANSWER": "적당한 부목이 없을 경우 환자의 전신 또는 일부분을 신문지 뭉치, 잡지, 담요, 베개 등을 대응 부목으로 사용할 수 있습니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "근육경련이 발생했을 때 어떻게 응급처치를 해야 하나요?",
#     "ANSWER": "환자를 눕혀 편안한 자세를 유지시키며 안정을 취하도록 하고, 경련 부위가 종아리 근육이거나 뒤쪽 허벅지인 경우 다리를 쭉 핀 상태에서 발목을 몸 쪽으로 서서히 당겨줍니다. 경련 부위가 허벅지 근육이면 다리부분을 뒤로 굽히는 등 근육경련이 발생한 근육을 반대편으로 당겨줍니다. 심호흡을 하며 안정을 취하고 해당근육을 가볍게 마사지 해줍니다. 따뜻한 물에 수건을 적셔 경련이 일어난 부분에 올려놓습니다."
# },
# {
#     "QUESTION": "근육경련을 예방하기 위해서는 어떤 방법이 좋은가요?",
#     "ANSWER": "근육경련을 예방하기 위해서는 평소 스트레칭을 꾸준히 실시하고, 충분한 수분섭취를 하는 것이 좋습니다."
# },
# {
#     "QUESTION": "근육경련이란 무엇인가요?",
#     "ANSWER": "근육경련이란 근육의 일부가 저절로 통증을 동반하면서 과도하게 수축되는 것을 말합니다."
# }
# ``````json
# {
#     "QUESTION": "출혈이 발생했을 때 가장 먼저 해야 할 응급처치는 무엇인가요?",
#     "ANSWER": "출혈이 발생했을 때 가장 먼저 해야 할 응급처치는 출혈 부위를 압박하여 출혈을 멈추는 것입니다."
# },
# {
#     "QUESTION": "출혈 부위를 압박할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "출혈 부위를 압박할 때는 깨끗한 천이나 거즈를 사용하여 직접 압박하고, 압박이 충분하지 않으면 압력을 더 가해야 합니다."
# },
# {
#     "QUESTION": "출혈이 심할 경우 어떻게 대처해야 하나요?",
#     "ANSWER": "출혈이 심할 경우 즉시 응급 의료 서비스를 요청하고, 출혈 부위를 계속 압박하여 출혈을 최소화해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "출혈이 심한 경우 나타날 수 있는 증상은 무엇인가요?",
#     "ANSWER": "출혈이 심한 경우 호흡과 맥박이 빨라지고 호흡 곤란이 발생할 수 있으며, 피부가 창백해지고 체온이 떨어질 수 있습니다. 또한 갈증을 느끼면서 동공이 확대되며 구토가 발생할 수도 있습니다."
# },
# {
#     "QUESTION": "출혈이란 무엇을 의미하나요?",
#     "ANSWER": "출혈이란 혈관의 손상에 의해 혈액이 혈관 밖으로 나오는 현상을 의미합니다."
# },
# {
#     "QUESTION": "스포츠 활동 중 출혈이 발생했을 때 어떤 응급처치가 필요한가요?",
#     "ANSWER": "작은 상처에 의한 출혈도 2차 감염의 위험성을 가지고 있으므로 소독, 지혈 등의 적절한 처치를 해야 하며 심한 출혈이 있을 경우에는 상처 부위나 크기에 따른 응급처치가 필요합니다."
# }
# ``````json
# {
#     "QUESTION": "직접 압박 지혈 방법은 무엇인가요?",
#     "ANSWER": "직접 압박 지혈은 출혈되는 상처부위를 소독거즈로 덮은 후 손으로 압박하여 지혈하는 방법입니다."
# },
# {
#     "QUESTION": "출혈이 멈추지 않을 때는 어떻게 해야 하나요?",
#     "ANSWER": "출혈이 멈추지 않으면 더 세게 압박하고, 적어도 10분 이상 상처를 압박하여 응고를 돕습니다."
# },
# {
#     "QUESTION": "지혈대는 언제 사용하나요?",
#     "ANSWER": "지혈대는 직접 압박 지혈과 동맥점 압박 지혈로 출혈을 멈출 수 없는 경우에 사용합니다."
# }
# ``````json
# {
#     "QUESTION": "직접 압박으로 지혈되지 않는 경우 어떤 방법을 사용하나요?",
#     "ANSWER": "직접 압박으로 지혈되지 않는 경우 해당 동맥과 가까운 지혈점을 압박함으로써 심한 출혈을 억제하는 방법을 사용합니다."
# },
# {
#     "QUESTION": "손의 출혈이 있을 때 어떤 동맥을 압박해야 하나요?",
#     "ANSWER": "손의 출혈이 있을 때는 요골동맥을 압박해야 합니다."
# },
# {
#     "QUESTION": "하지 출혈 시 어떤 동맥을 압박해야 하나요?",
#     "ANSWER": "하지 출혈 시에는 대퇴동맥을 압박해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "지혈대는 언제 사용해야 하나요?",
#     "ANSWER": "지혈대는 직접 압박과 혈관 압박으로도 출혈을 멈출 수 없을 때에 사용되는 방법입니다."
# },
# {
#     "QUESTION": "지혈대를 사용할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "지혈대를 사용할 때는 신경이나 혈관에 손상을 줄 수 있으며 팔이나 다리에 괴사를 초래할 수 있으므로 일정한 시간마다 지혈대를 풀어서 괴사를 방지하는 것이 중요합니다."
# },
# {
#     "QUESTION": "지혈대를 사용한 후에는 어떻게 해야 하나요?",
#     "ANSWER": "지혈대를 맨 후 시간이 오래 경과하지 않도록 하고 신속히 병원으로 이송해야 합니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "충격에 의해 신체 손상을 입었을 때 가장 먼저 해야 할 응급처치는 무엇인가요?",
#         "ANSWER": "충격에 의해 신체 손상을 입었을 때는 즉시 손상 부위를 확인하고, 출혈이 있는 경우에는 지혈을 시도하며, 가능한 한 빨리 의료 전문가의 도움을 받는 것이 중요합니다."
#     },
#     {
#         "QUESTION": "응급처치 시 주의해야 할 사항은 무엇인가요?",
#         "ANSWER": "응급처치 시에는 손상 부위를 과도하게 움직이지 않도록 주의하고, 감염을 방지하기 위해 손을 깨끗이 씻고 멸균된 도구를 사용하는 것이 중요합니다."
#     },
#     {
#         "QUESTION": "응급처치 후 병원에 가야 하는 경우는 언제인가요?",
#         "ANSWER": "응급처치 후에도 출혈이 멈추지 않거나, 심한 통증이 지속되거나, 의식이 혼미한 경우에는 즉시 병원에 가야 합니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "뇌진탕이 발생했을 때 의식이 없는 경우 어떻게 해야 하나요?",
#     "ANSWER": "환자의 의식 여부를 확인한 후 의식이 없다면 즉시 심폐소생술을 실시해야 합니다."
# },
# {
#     "QUESTION": "뇌진탕으로 인해 부딪힌 부분이 부었을 때 어떻게 처치해야 하나요?",
#     "ANSWER": "부딪힌 부분이 부었을 경우 차가운 찜질을 해주고 눕힌 상태에서 상체만 일으켜 앉힌 후 넘어지지 않게 상체를 기대게 합니다."
# },
# {
#     "QUESTION": "뇌진탕 후 어떤 증상이 나타나면 병원에 가서 정밀검사를 받아야 하나요?",
#     "ANSWER": "안정을 취한 뒤에도 기력저하, 기억상실 등의 증세를 보이면 병원에 가서 정밀검사를 받아야 합니다."
# }
# ``````json
# {
#     "QUESTION": "치아가 흔들릴 경우 어떻게 응급처치를 해야 하나요?",
#     "ANSWER": "치아가 흔들릴 경우에는 잇몸을 깨끗한 천 등으로 눌러 지혈하고, 통증과 흔들림이 지속된다면 최대한 빠른 시간내에 병원을 내원하여 진료를 받아야 합니다."
# },
# {
#     "QUESTION": "치아가 빠졌을 때 어떻게 응급처치를 해야 하나요?",
#     "ANSWER": "치아가 빠졌을 경우 치아의 뿌리 부분인 치근을 만지지 말고 치아의 머리 부분인 치관을 잡아 흐르는 찬물에 10초 동안 헹궈준 후 빠진 치아자리에 밀어 넣고 신속히 병원으로 가야 합니다. 치아를 밀어 넣지 못했을 경우에는 우유나 식염수, 수돗물에 담가 치아를 마르지 않게 한 후 병원으로 가는 것이 좋습니다."
# },
# {
#     "QUESTION": "치아 손상 시 병원을 얼마나 빨리 찾아야 하나요?",
#     "ANSWER": "치아 손상을 입었을 경우에는 1시간 이내로 병원을 찾아야 합니다. 치아뿌리의 치근막 세포가 정상적으로 살아있다면 인공치아 대신 자신의 치아를 살려 치료할 수 있기 때문입니다."
# }
# ``````json
# {
#     "QUESTION": "두개골 골절 시 어떤 증상이 나타날 수 있나요?",
#     "ANSWER": "두개골 골절 시 극심한 통증과 머리 모양의 변형 또는 상처의 흔적이 생기며, 두피가 안쪽으로 들어가거나 말랑말랑한 혹이 생기고 머리, 얼굴 모양이 변형될 수 있습니다."
# },
# {
#     "QUESTION": "두개골 골절 환자를 응급처치할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "환자를 무리하게 옮기거나 처치하지 않으며, 환자의 의식 여부를 확인한 후 의식이 없다면 환자를 눕히고 머리와 어깨를 들어서 부드러운 것으로 받칩니다. 이때 다리보다 어깨를 높게 유지합니다."
# },
# {
#     "QUESTION": "두개골 골절 시 출혈이 있을 경우 어떻게 해야 하나요?",
#     "ANSWER": "부상 부위의 출혈을 깨끗한 수건 등으로 지혈하면서 119 구급대를 기다립니다. 귀나 코에서 흐르는 뇌척수액은 절대로 막거나 닦아내지 말고 흘러내리게 합니다."
# }
# ``````json
# {
#     "QUESTION": "온도변화로 인한 신체손상에는 어떤 종류가 있나요?",
#     "ANSWER": "온도변화로 인한 신체손상에는 저체온증과 열사병이 포함됩니다."
# },
# {
#     "QUESTION": "저체온증이 발생했을 때 응급처치는 어떻게 해야 하나요?",
#     "ANSWER": "저체온증이 발생했을 때는 따뜻한 장소로 옮기고, 젖은 옷을 제거한 후 따뜻한 담요로 몸을 감싸 체온을 유지해야 합니다."
# },
# {
#     "QUESTION": "열사병이 의심될 때는 어떤 조치를 취해야 하나요?",
#     "ANSWER": "열사병이 의심될 때는 즉시 시원한 장소로 옮기고, 옷을 느슨하게 하며, 물을 마시게 하여 체온을 낮추는 것이 중요합니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "고온 환경에서 열사병을 예방하기 위해 어떤 조치를 취해야 하나요?",
#         "ANSWER": "고온 환경에서 열사병을 예방하기 위해서는 날씨, 의복 착용 상태, 스포츠 환경, 각 개인의 건강 상태 등을 확인한 후 스포츠 활동에 참가해야 합니다."
#     },
#     {
#         "QUESTION": "저온 환경에서 동상을 방지하기 위해 어떤 준비가 필요합니까?",
#         "ANSWER": "저온 환경에서 동상을 방지하기 위해서는 날씨, 의복 착용 상태, 스포츠 환경, 각 개인의 건강 상태 등을 확인한 후 스포츠 활동에 참가해야 합니다."
#     },
#     {
#         "QUESTION": "온도변화로 인한 신체손상에는 어떤 종류가 있나요?",
#         "ANSWER": "온도변화로 인한 신체손상에는 고온에서 발생하는 화상과 열사병, 저온에서 발생하는 동상과 저체온증이 있습니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "화상을 입었을 때 피부의 열기를 줄이기 위해 어떻게 해야 하나요?",
#     "ANSWER": "피부의 열기를 줄이기 위해 흐르는 물에 15분 이상 환부를 차게 합니다."
# },
# {
#     "QUESTION": "화상 부위의 옷을 벗길 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "화상 부위의 옷을 벗길 때 무리하게 옷을 벗겨 물집이 벗겨지거나 터트리지 않도록 주의해야 합니다."
# },
# {
#     "QUESTION": "경미한 화상을 제외한 경우, 환자를 어떻게 해야 하나요?",
#     "ANSWER": "경미한 화상을 제외하고 환자를 병원으로 후송합니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "화상 부위에 옷이 달라붙었을 때는 어떻게 해야 하나요?",
#         "ANSWER": "화상 부위에 옷이 달라붙었다면 옷을 벗기다 피부에 손상을 줄 수 있으니 가위를 이용해 옷을 찢어야 합니다."
#     },
#     {
#         "QUESTION": "화상 부위에 얼음을 대면 안 되는 이유는 무엇인가요?",
#         "ANSWER": "화상 부위에 얼음을 대면 혈관 수축으로 염증성 물집이 생성되어 증상을 더욱 악화시킬 수 있습니다."
#     },
#     {
#         "QUESTION": "화상 치료 후 상처 부위를 보호하기 위해 어떤 조치를 취해야 하나요?",
#         "ANSWER": "화상 치료 후 상처가 자외선에 노출되면 피부 변색을 일으킬 수 있으므로 자외선차단제를 바르고 상처부위를 가리는 부드러운 면 소재의 옷을 입는 것이 좋습니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "열사병이 발생했을 때 나타날 수 있는 증상은 무엇인가요?",
#     "ANSWER": "열사병이 발생했을 때 체온이 40도까지 상승할 수 있으며, 땀을 흘리지 않거나 의식 및 행동의 변화(가벼운 혼동, 지남력상실, 무의식)가 나타날 수 있습니다."
# },
# {
#     "QUESTION": "열사병 환자에게 가장 중요한 응급처치 방법은 무엇인가요?",
#     "ANSWER": "열사병 환자의 경우 몸을 식혀주고 수분을 섭취하는 것이 중요합니다. 즉시 환자를 시원한 곳으로 옮기면 체온 조절 중추의 기능이 곧 회복되어 체온이 신속하게 떨어집니다."
# },
# {
#     "QUESTION": "열사병 환자의 의식이 있는 경우 어떻게 수분을 보충해야 하나요?",
#     "ANSWER": "환자의 의식이 있는 경우 시원한 물을 천천히 먹도록 하여 모자라는 수분을 보충합니다."
# }
# ``````json
# {
#     "QUESTION": "일사병이 발생했을 때 응급처치 방법은 무엇인가요?",
#     "ANSWER": "일사병이 발생했을 때는 환자를 그늘진 시원한 장소로 옮기고 옷을 벗긴 후에 편안한 자세를 취하게 합니다. 다리를 편 상태로 20~30cm 정도 높여주고, 입으로 소금이 들어간 찬 물 또는 이온음료를 마시게 합니다. 찬물을 묻힌 스펀지로 몸을 적신 후에 부채질을 해줍니다."
# },
# {
#     "QUESTION": "일사병 발생 시 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "일사병 발생 시 알약 형태의 소금덩어리는 위를 자극하고, 메스꺼움과 구토를 유발할 수 있으므로 주지 않는 것이 좋습니다. 또한, 술 또는 카페인은 체온 조절기능을 방해하므로 이것이 들어 있는 음료수는 주지 않는 것이 좋습니다."
# },
# {
#     "QUESTION": "일사병과 열사병의 차이점은 무엇인가요?",
#     "ANSWER": "일사병은 체온과 의식 변화 측면에서 대부분 정상처럼 보이는 경우가 많으나, 열사병은 고열 또는 의식 변화가 발생할 수 있습니다."
# }
# ``````json
# {
#     "QUESTION": "동상이란 무엇인가요?",
#     "ANSWER": "동상은 신체 조직의 일부가 언 상태를 의미하며, 주로 스포츠 활동 시 저온에 노출된 신체 부위에 발생합니다."
# },
# {
#     "QUESTION": "동상이 발생했을 때 응급처치 방법은 무엇인가요?",
#     "ANSWER": "동상 부위를 매우 조심스럽게 다루고, 추운 곳에서 벗어나 따뜻한 곳으로 이동하며, 젖은 옷을 마른 옷으로 갈아입고 손상부위를 따뜻한 담요 등으로 감싸면서 서서히 따뜻하게 해줍니다."
# },
# {
#     "QUESTION": "동상 부위를 문지르면 안 되는 이유는 무엇인가요?",
#     "ANSWER": "동상 부위를 문지르면 손상부위가 더 악화될 수 있기 때문에 절대 문지르지 않아야 합니다."
# }
# ``````json
# {
#     "QUESTION": "저체온증이 발생했을 때 가장 먼저 해야 할 일은 무엇인가요?",
#     "ANSWER": "저체온증이 발생했을 때 가장 먼저 해야 할 일은 즉시 119에 신고하는 것입니다."
# },
# {
#     "QUESTION": "저체온증 환자를 따뜻하게 하기 위해 어떤 조치를 취해야 하나요?",
#     "ANSWER": "저체온증 환자를 따뜻하게 하기 위해 젖은 옷을 벗기고 마른 옷으로 갈아입혀서 열손실을 방지하고, 환자의 머리를 찬 공기로부터 보호합니다."
# },
# {
#     "QUESTION": "저체온증 환자에게 급속 가온치료를 하면 안 되는 이유는 무엇인가요?",
#     "ANSWER": "저체온증 환자에게 급속 가온치료를 하면 말초의 차가운 혈액을 순환시켜 심정지를 일으킬 수 있기 때문에 하지 않습니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "응급처치가 필요한 질환에는 어떤 것들이 있나요?",
#         "ANSWER": "응급처치가 필요한 질환에는 화상, 벌에 쏘임, 골절 등이 있습니다."
#     },
#     {
#         "QUESTION": "응급처치 시 주의해야 할 점은 무엇인가요?",
#         "ANSWER": "응급처치 시에는 상처 부위를 깨끗하게 유지하고, 가능한 경우 멸균 처리된 거즈를 사용하여 감염을 방지해야 합니다."
#     },
#     {
#         "QUESTION": "응급처치의 목적은 무엇인가요?",
#         "ANSWER": "응급처치의 목적은 부상이나 질환으로 인한 추가적인 손상을 방지하고, 환자의 상태를 안정화하여 전문적인 치료를 받을 수 있도록 돕는 것입니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "뇌졸중의 주요 증상은 무엇인가요?",
#     "ANSWER": "뇌졸중의 주요 증상으로는 얼굴이 한쪽으로 일그러지고, 한쪽 팔의 감각이 없으며, 말이 새고 말하는 데 어려움이 있습니다."
# },
# {
#     "QUESTION": "뇌졸중 발생 시 가장 먼저 해야 할 조치는 무엇인가요?",
#     "ANSWER": "뇌졸중 발생 시 가장 먼저 해야 할 조치는 즉시 119에 신고하여 최대한 빨리 병원에 도착하도록 조치를 취하는 것입니다."
# },
# {
#     "QUESTION": "뇌졸중이 발생하면 뇌에 어떤 영향이 있나요?",
#     "ANSWER": "뇌졸중이 발생하면 뇌에 산소와 영양분 공급이 중단되어 뇌의 기능이 상실되고 사지마비나 언어 장애, 시야장애 등의 장애가 발생할 수 있습니다."
# }
# ``````json
# {
#     "QUESTION": "뇌졸중 환자를 발견했을 때 가장 먼저 해야 할 일은 무엇인가요?",
#     "ANSWER": "뇌졸중 환자를 발견하면 즉시 119에 신고한 뒤, 사고가 난 시간을 확인하고 환자의 상태를 관찰해야 합니다."
# },
# {
#     "QUESTION": "뇌졸중 환자에게 약이나 물을 먹이면 안 되는 이유는 무엇인가요?",
#     "ANSWER": "뇌졸중 시에는 뇌가 멈춰 기침을 할 수 없기 때문에 약이나 물을 먹이는 행위는 환자를 사망에 이르게 할 수 있습니다."
# },
# {
#     "QUESTION": "뇌졸중 환자를 발견했을 때 몸을 흔들거나 얼굴을 치면 안 되는 이유는 무엇인가요?",
#     "ANSWER": "뇌졸중 환자의 몸을 흔들거나 얼굴을 치는 행위는 환자의 뇌혈관 출혈을 더욱 악화시키고 환자의 혈압을 올려 사망에 이르게 할 수 있습니다."
# }
# ``````json
# {
#     "QUESTION": "천식 환자가 스포츠 활동을 할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "천식 환자는 기관지의 문제로 호흡이 어려워질 수 있으므로 갑작스럽고 격렬한 활동은 피하는 것이 좋습니다."
# },
# {
#     "QUESTION": "천식으로 인한 응급상황에 대비하기 위해 현장에 비치해야 할 것은 무엇인가요?",
#     "ANSWER": "천식 환자들이 언제든 사용할 수 있도록 응급용 기관지 확장제를 현장에 비치하는 것이 좋습니다."
# },
# {
#     "QUESTION": "천식의 주요 증상은 무엇인가요?",
#     "ANSWER": "천식의 주요 증상은 호흡곤란, 기침, 그리고 천명(쌕쌕거림)입니다."
# }
# ``````json
# {
#     "QUESTION": "당뇨병 환자가 저혈당 쇼크를 예방하기 위해 운동 시 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "당뇨병 환자는 과도한 신체활동을 피하고, 공복 상태에서 운동을 하지 않도록 주의해야 합니다. 운동 전 식사와 컨디션을 체크하고 틈틈이 간식을 섭취하는 것이 좋습니다."
# },
# {
#     "QUESTION": "당뇨병 환자에게 적당한 운동이 왜 중요한가요?",
#     "ANSWER": "당뇨병 환자의 적당한 운동은 비만을 예방하고 칼로리를 소모시키며, 혈당을 떨어뜨리고 스트레스와 피로를 해소하는 데 효과적입니다."
# },
# {
#     "QUESTION": "저혈당 쇼크의 위험 요인에는 어떤 것들이 있나요?",
#     "ANSWER": "저혈당 쇼크의 위험 요인으로는 과도한 운동과 공복 상태에서의 운동이 있습니다."
# }
# ``````json
# {
#     "QUESTION": "저혈당 쇼크가 발생했을 때 의식이 있는 경우 어떻게 응급처치를 해야 하나요?",
#     "ANSWER": "의식이 있는 경우 빨리 흡수되어 혈당을 올릴 수 있는 당질음식인 설탕물이나 꿀, 초콜릿, 각설탕 등을 섭취하도록 한 후, 운동을 멈추고 휴식하게 합니다."
# },
# {
#     "QUESTION": "저혈당 쇼크가 발생했을 때 의식이 없는 경우 어떻게 응급처치를 해야 하나요?",
#     "ANSWER": "의식이 없는 경우 무리하게 음식물을 먹이려고 하면 음식물이 기도로 넘어가 호흡곤란이나 폐렴을 유발할 수 있으므로 즉시 병원으로 옮겨서 포도당 주사를 맞도록 합니다."
# },
# {
#     "QUESTION": "길가에 쓰러져 있는 사람을 발견했을 때 당뇨병 환자인지 확인하는 방법은 무엇인가요?",
#     "ANSWER": "길가에 쓰러져 있는 사람을 발견했을 때 당뇨병 환자인지 의심해보고 '저는 당뇨병이 있습니다.'라는 인식표가 있는지 확인해 봅니다."
# }
# ``````json
# {
#     "QUESTION": "스포츠 현장에서 발생하는 재난 사고에 대한 일반적인 대응 절차는 무엇인가요?",
#     "ANSWER": "스포츠 현장에서 발생하는 재난 사고에 대한 대응 절차는 사고의 종류에 따라 다르며, 각 사고에 맞는 적절한 응급처치와 안전 조치를 취하는 것이 중요합니다."
# },
# {
#     "QUESTION": "스포츠 현장에서 심정지가 발생했을 때 어떻게 대처해야 하나요?",
#     "ANSWER": "스포츠 현장에서 심정지가 발생했을 때는 즉시 심폐소생술(CPR)을 시작하고, 가능한 빨리 자동 심장 충격기(AED)를 사용하여 심장 리듬을 회복시켜야 합니다."
# },
# {
#     "QUESTION": "스포츠 현장에서 발생할 수 있는 열사병의 초기 증상은 무엇인가요?",
#     "ANSWER": "스포츠 현장에서 발생할 수 있는 열사병의 초기 증상으로는 두통, 어지러움, 피로감, 구역질 등이 있으며, 이러한 증상이 나타나면 즉시 시원한 곳으로 이동하여 체온을 낮추는 조치를 취해야 합니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "스포츠 활동 중 화재가 발생했을 때 어떻게 대처해야 하나요?",
#         "ANSWER": "화재가 발생했을 때는 즉시 안전한 장소로 대피하고, 화재 경보를 울려 다른 사람들에게 알립니다. 또한, 소화기를 사용하여 초기 진화를 시도할 수 있습니다."
#     },
#     {
#         "QUESTION": "수중 스포츠 참여 중 익사 사고가 발생했을 때 어떻게 대처해야 하나요?",
#         "ANSWER": "익사 사고가 발생했을 때는 즉시 구조 요청을 하고, 가능한 경우 물에 빠진 사람을 안전하게 물 밖으로 끌어내어 인공호흡과 심폐소생술을 실시합니다."
#     },
#     {
#         "QUESTION": "스포츠 현장에서 테러가 발생했을 때 어떻게 대처해야 하나요?",
#         "ANSWER": "테러가 발생했을 때는 즉시 안전한 장소로 대피하고, 경찰이나 보안 요원에게 상황을 알립니다. 또한, 주변 사람들에게도 경고하여 안전하게 대피할 수 있도록 돕습니다."
#     }
# ]
# ``````json
# [
#     {
#         "QUESTION": "화재가 발생했을 때 가장 먼저 해야 할 일은 무엇인가요?",
#         "ANSWER": "화재가 발생했을 때 가장 먼저 해야 할 일은 '불이야'하고 큰소리로 외쳐 다른 사람들에게 알리는 것입니다."
#     },
#     {
#         "QUESTION": "화재 발생 시 119에 신고할 때 어떤 정보를 제공해야 하나요?",
#         "ANSWER": "화재 발생 시 119에 신고할 때는 불이 난 사실을 말하며 화재의 내용을 간단하고 명료하게 설명하고, 주소를 알려줘야 합니다."
#     },
#     {
#         "QUESTION": "화재 신고 후 전화를 끊을 때 주의해야 할 점은 무엇인가요?",
#         "ANSWER": "화재 신고 후에는 119에서 전화를 끊으라고 하기 전에 먼저 전화를 끊지 않아야 합니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "연기가 많은 경우 어떻게 대피해야 하나요?",
#     "ANSWER": "연기가 많은 경우에는 연기층 아래에 맑은 공기층이 있기 때문에 최대한 낮은 자세로 팔과 무릎으로 기어서 이동하되, 바닥에 배를 대고 가지 않습니다. 또한 코와 입을 젖은 수건 등으로 막아 연기가 폐에 들어가지 않도록 합니다."
# },
# {
#     "QUESTION": "불길 속을 통과해야 할 때는 어떻게 해야 하나요?",
#     "ANSWER": "불길 속을 통과할 때는 온몸에 물을 뿌리거나 물에 적신 담요 또는 수건 등으로 몸과 얼굴을 잘 감싼 후 대피합니다. 옷에 불이 붙었을 때에는 두 손으로 눈과 입을 가리고 바닥에서 뒹굽니다."
# },
# {
#     "QUESTION": "건물 밖으로 대피할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "건물 밖으로 대피할 때는 승강기를 절대 이용하지 않고 계단을 이용합니다. 아래층으로 대피하지 못하는 경우 옥상으로 대피합니다."
# }
# ``````json
# {
#     "QUESTION": "소규모 화재 발생 시 어떤 소화기를 사용하는 것이 바람직한가요?",
#     "ANSWER": "소규모 화재 발생 시 분말소화기와 투척용 소화기를 사용하는 것이 바람직합니다."
# },
# {
#     "QUESTION": "분말 소화기를 사용할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "분말 소화기를 사용할 때는 바람을 뒤로하고 소화기 호스를 불이 난 곳으로 향하게 잡고, 소화기 안전핀을 뽑은 후 손잡이를 꽉 잡고 불을 향해 빗자루로 쓸 듯이 소화액을 뿌려야 합니다."
# },
# {
#     "QUESTION": "투척용 소화기는 어떻게 사용하나요?",
#     "ANSWER": "투척용 소화기는 커버를 벗기고 약재를 꺼낸 후 불을 향해 던져 사용합니다."
# }
# ``````json
# {
#     "QUESTION": "지진 발생 시 실내에서 어떻게 대처해야 하나요?",
#     "ANSWER": "실내 스포츠의 경우 운동을 즉시 중단한 후 책상 또는 탁자 밑으로 몸을 피하고 넘어지기 쉬운 물건 주변은 피해야 합니다."
# },
# {
#     "QUESTION": "지진 발생 시 실외에서 어떻게 대처해야 하나요?",
#     "ANSWER": "실외 운동의 경우 운동을 즉시 중단하고 위험 요소(담장, 간판, 산사태 등)를 피해 넓은 공터로 대피해야 합니다."
# },
# {
#     "QUESTION": "천재지변 사고의 종류에는 어떤 것들이 있나요?",
#     "ANSWER": "천재지변 사고의 종류에는 지진, 집중호우·태풍, 폭염·폭설, 천둥·번개·낙뢰 등이 있습니다."
# }
# ``````json
# {
#     "QUESTION": "집중호우나 태풍 발생 시 수상스포츠 중에는 어떻게 대처해야 하나요?",
#     "ANSWER": "집중호우나 태풍 발생 시 수상스포츠 중에는 조명시설 및 고압전선 근처에 가지 않고, 실외 운동을 즉시 중단하고 가까운 건물 내부로 이동해야 합니다."
# },
# {
#     "QUESTION": "집중호우가 발생했을 때 물건은 어떻게 해야 하나요?",
#     "ANSWER": "집중호우가 발생했을 때 물에 떠내려가거나 바람에 날아갈 위험이 있는 물건은 안전한 장소로 옮겨야 합니다."
# },
# {
#     "QUESTION": "태풍의 정의는 무엇인가요?",
#     "ANSWER": "태풍은 열대해상에서 발생하는 열대성 저기압 중 중심 부근의 최대 풍속이 17m/s 이상으로 주변 지역에 폭풍우를 동반하는 기상현상입니다."
# }
# ``````json
# {
#     "QUESTION": "폭염 발생 시 실외 운동을 하고 있을 때 어떻게 대처해야 하나요?",
#     "ANSWER": "폭염 발생 시 실외 운동을 하고 있을 때는 즉시 운동을 중단하고 통풍이 잘 되는 그늘이나 선풍기 및 에어컨이 작동되는 실내로 이동해야 합니다."
# },
# {
#     "QUESTION": "폭설 발생 시 신체 끝부분을 보호하기 위해 어떤 조치를 취해야 하나요?",
#     "ANSWER": "폭설 발생 시 신체 끝부분은 동상이 걸리기 쉬우므로 장갑, 두꺼운 양말, 모자 등으로 체온을 유지해야 합니다."
# },
# {
#     "QUESTION": "폭염과 폭설의 정의는 무엇인가요?",
#     "ANSWER": "폭염은 갑작스럽게 찾아오는 심한 더위를 말하며 일반적으로 30℃ 이상의 더위가 계속되는 현상입니다. 폭설은 짧은 시간에 많은 양의 눈이 오는 현상으로, 평소에 눈이 올 때보다 더 많은 눈이 내려 피해가 예상되는 경우를 의미합니다."
# }
# ``````json
# {
#     "QUESTION": "낙뢰에 맞았을 경우 의식이 없는 환자에게는 어떻게 응급처치를 해야 하나요?",
#     "ANSWER": "낙뢰에 맞아 의식이 없는 환자에게는 즉시 기도를 열어 호흡을 하는지 확인하고, 호흡을 하지 않으면 인공호흡과 함께 심장마사지를 합니다."
# },
# {
#     "QUESTION": "천둥과 번개가 예상될 때 스포츠 활동 중인 사람들은 어떻게 대처해야 하나요?",
#     "ANSWER": "천둥과 번개가 예상되면 스포츠 활동을 중단하고 참여자들이 최대한 몸을 낮춰 실내로 대피하거나, 움푹 파인 곳으로 대피할 수 있도록 유도합니다."
# },
# {
#     "QUESTION": "수상활동 중 번개를 처음 보거나 천둥소리를 들었을 때는 어떻게 해야 하나요?",
#     "ANSWER": "수상활동 중 번개를 처음 보거나 천둥소리를 들었을 때는 즉시 물에서 나오도록 하며 안전한 큰 건물로 대피할 수 있도록 합니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "붕괴사고 발생 시 건물 안에서 어떻게 대처해야 하나요?",
#         "ANSWER": "붕괴사고 발생 시 당황하지 않고 건물을 빠져나갈 수 있는 대피 경로를 찾아야 하며, 유리파편이나 떨어지는 물건에 다치지 않도록 옷 등으로 머리와 얼굴을 보호해야 합니다."
#     },
#     {
#         "QUESTION": "붕괴사고 시 부상자를 어떻게 처리해야 하나요?",
#         "ANSWER": "붕괴사고 시 부상자는 가능한 응급처치를 한 후 함께 탈출해야 합니다."
#     },
#     {
#         "QUESTION": "붕괴사고 후 건물 밖으로 나왔을 때 주의해야 할 점은 무엇인가요?",
#         "ANSWER": "붕괴사고 후 건물 밖으로 나오면 추가붕괴, 가스폭발, 화재 등에 대비하여 위험이 없는 안전한 지역으로 대피해야 합니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "붕괴된 건물에 갇혔을 때 체력을 어떻게 보존해야 하나요?",
#     "ANSWER": "붕괴된 건물에 갇혔을 때는 불필요한 활동이나 고함으로 체력을 소모하지 말고 가급적 편안한 자세를 유지해야 합니다."
# },
# {
#     "QUESTION": "붕괴의 예비 징후 중 하나는 무엇인가요?",
#     "ANSWER": "붕괴의 예비 징후 중 하나는 문이나 창문이 뒤틀리고 열고 닫기가 곤란할 때입니다."
# },
# {
#     "QUESTION": "붕괴된 건물에서 먼지 흡입을 최소화하기 위해 어떻게 해야 하나요?",
#     "ANSWER": "붕괴된 건물에서 먼지 흡입을 최소화하기 위해 입과 코를 옷 등으로 가려야 합니다."
# }
# ``````json
# {
#     "QUESTION": "테러 사고 중 폭발물이 사용된 경우 어떻게 대처해야 하나요?",
#     "ANSWER": "폭발물이 사용된 테러 사고에서는 즉시 안전한 장소로 대피하고, 부상자가 발생한 경우 응급처치를 제공하며, 가능한 한 빨리 전문 의료진의 도움을 받도록 해야 합니다."
# },
# {
#     "QUESTION": "총격 테러가 발생했을 때는 어떻게 해야 하나요?",
#     "ANSWER": "총격 테러가 발생했을 때는 즉시 몸을 숨길 수 있는 안전한 장소로 이동하고, 경찰이나 보안 요원에게 상황을 알리며, 부상자가 있을 경우 응급처치를 시도하되 자신의 안전을 최우선으로 고려해야 합니다."
# },
# {
#     "QUESTION": "화학물 테러가 발생했을 때는 어떻게 대처해야 하나요?",
#     "ANSWER": "화학물 테러가 발생했을 때는 즉시 오염된 지역을 벗어나고, 노출된 피부나 옷을 깨끗한 물로 씻어내며, 가능한 한 빨리 의료진의 도움을 받아야 합니다."
# }
# ``````json
# {
#     "QUESTION": "총격테러 발생 시 어떻게 대처해야 하나요?",
#     "ANSWER": "총기 난사 시 일단 엎드린 후 상황을 살피는 것이 최선입니다. 항상 낮은 자세를 유지하고, 상황이 허락하는 대로 즉시 '111' 또는 '112'에 신고합니다."
# },
# {
#     "QUESTION": "폭발물테러 발생 시 대피할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "폭발물 발견 시 즉시 반대방향으로 대피하며, 승강기는 사용하지 않고 계단으로 대피합니다. 휴대전화, 라디오, 무전기 등은 기폭장치를 작동시킬 수 있으므로 사용하지 않아야 합니다."
# },
# {
#     "QUESTION": "방사능테러 발생 시 방사능에 노출되었다고 판단되면 어떻게 해야 하나요?",
#     "ANSWER": "방사능에 노출되었다고 판단되면 오염된 옷을 벗고 온몸을 깨끗하게 씻습니다."
# }
# ``````json
# {
#     "QUESTION": "납치·감금 상황에서 탈출을 시도해야 할 때는 언제인가요?",
#     "ANSWER": "납치·감금 시 탈출 가능성이 높지 않으면 탈출을 시도하지 않습니다."
# },
# {
#     "QUESTION": "화학물질에 노출되었을 때 가장 먼저 해야 할 일은 무엇인가요?",
#     "ANSWER": "화학물질에 노출된 경우, 즉시 '111' 또는 '112'에 신고합니다."
# },
# {
#     "QUESTION": "화학테러 발생 시 차량으로 이동할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "차량으로 이동할 때에는 창문을 닫고 에어컨과 히터를 켜지 않습니다."
# }
# ``````json
# {
#     "QUESTION": "테러 의심 우편물을 발견했을 때 가장 먼저 해야 할 일은 무엇인가요?",
#     "ANSWER": "테러 의심 우편물을 발견했을 때는 즉시 '111' 또는 '112'에 신고해야 합니다."
# },
# {
#     "QUESTION": "화생방 물질이 포함된 우편물을 개봉했을 경우 어떻게 대처해야 하나요?",
#     "ANSWER": "화생방 물질이 포함된 우편물을 개봉했을 경우 우편물에 접촉하지 말고 수건으로 코와 입을 막고 우편물 개봉장소를 즉시 떠나야 합니다."
# },
# {
#     "QUESTION": "사제폭탄이 포함된 우편물을 개봉했을 때의 대처 방법은 무엇인가요?",
#     "ANSWER": "사제폭탄이 포함된 우편물을 개봉했을 때는 즉시 그 장소를 떠난 후 '111' 또는 '112'에 신고해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "바다에 빠졌을 때 체력 소모를 줄이기 위한 방법은 무엇인가요?",
#     "ANSWER": "바다에 빠졌을 때 체력 소모를 줄이기 위해서는 긴장을 풀고 몸에 힘을 최대한 뺀 상태로 수영하는 것이 중요합니다."
# },
# {
#     "QUESTION": "수중에서 경련이 발생했을 때 어떻게 대처해야 하나요?",
#     "ANSWER": "수중에서 경련이 발생했을 때 가장 중요한 것은 근육을 펴는 것입니다. 당황해서 몸을 함부로 움직이면 익사 위험이 있으므로 주의해야 합니다."
# },
# {
#     "QUESTION": "큰 파도에 휩싸였을 때 어떻게 해야 하나요?",
#     "ANSWER": "큰 파도에 휩싸였을 때는 버둥거리지 않고 파도에 몸을 맡긴 후 숨을 크게 들이마시고 중지해 있으면 자연스럽게 몸이 떠오릅니다."
# }
# ``````json
# {
#     "QUESTION": "물에서 경련이 발생했을 때 첫 번째로 해야 할 일은 무엇인가요?",
#     "ANSWER": "몸을 둥글게 모으고 물위에 뜨도록 합니다."
# },
# {
#     "QUESTION": "경련이 발생한 경우, 물속에서 어떻게 해야 하나요?",
#     "ANSWER": "숨을 크게 들이마시고 물속에 얼굴을 넣은 채 근육 경련이 풀릴 때까지 쥐가 난 쪽의 엄지발가락을 힘껏 앞으로 꺾어 잡아당깁니다."
# },
# {
#     "QUESTION": "경련이 가라앉은 후에는 어떤 조치를 취해야 하나요?",
#     "ANSWER": "경련이 가라앉아도 다시 경련이 일어날 가능성이 있으므로 물 밖에서 근육 경련 부위를 충분히 마사지 해줍니다."
# }
# ``````json
# {
#     "QUESTION": "셔츠를 이용하여 물에 뜨게 하는 방법은 무엇인가요?",
#     "ANSWER": "셔츠의 목 쪽에 공기가 새지 않게 조이고, 숨을 크게 들이마신 후 둘째와 셋째 단추 사이로 공기를 불어 넣으면 셔츠의 등 쪽에 물거품 모양이 형성되어 뜰 수 있습니다."
# },
# {
#     "QUESTION": "바지를 이용하여 물에 뜨게 하는 방법은 무엇인가요?",
#     "ANSWER": "바지의 발목 쪽을 공기가 새지 않도록 단단하게 묶고, 허리 좌우를 양손으로 잡고 머리 뒤로 넘긴 후 양손을 앞쪽 수면을 향해 강하게 내리치며 바지의 허리 쪽을 통해 공기가 들어가도록 하면 바지의 다리 쪽에 공기가 들어가 뜰 수 있습니다."
# },
# {
#     "QUESTION": "조류에 휘말렸을 때 어떻게 수영해야 하나요?",
#     "ANSWER": "조류에 휘말렸을 때는 당황하거나 피하려고 몸부림치지 말고 조류를 따라서 비스듬히 해변을 향해 헤엄쳐야 합니다."
# }
# ``````json
# {
#     "QUESTION": "수중에서 익수자를 발견했을 때 가장 먼저 해야 할 일은 무엇인가요?",
#     "ANSWER": "익수자를 발견한 경우 주변에 큰 소리로 '사람이 빠졌습니다. 119에 신고해주세요.'라고 외쳐서 모두가 알 수 있도록 합니다."
# },
# {
#     "QUESTION": "익수자를 구조할 때 직접 물에 뛰어드는 것은 언제 해야 하나요?",
#     "ANSWER": "직접 물에 뛰어드는 것은 최후의 수단입니다. 무턱대고 입수하기 보다는 주변 상황을 빠르게 살펴보고 익수자에게 물에 떠 있을 수 있도록 도와주는 장비를 제공하는 것이 안전합니다."
# },
# {
#     "QUESTION": "의식이 있는 익수자를 구조할 때 접근 방법은 어떻게 해야 하나요?",
#     "ANSWER": "의식이 있는 익수자를 구조할 때에는 반드시 뒤쪽으로부터 접근합니다."
# }
# ``````json
# {
#     "QUESTION": "의식이 없는 사고자를 구조하였을 때 가장 먼저 해야 할 응급처치는 무엇인가요?",
#     "ANSWER": "의식이 없는 사고자를 구조하였을 때 가장 먼저 해야 할 응급처치는 인공호흡입니다."
# },
# {
#     "QUESTION": "물에 빠진 사람을 발견했을 때 물속으로 뛰어들어 구조해야 하나요?",
#     "ANSWER": "물에 빠진 사람을 발견했을 때 절대로 물속으로 뛰어들어 구조하지 않습니다."
# },
# {
#     "QUESTION": "익사사고 발견 시 누구에게 신고해야 하나요?",
#     "ANSWER": "익사사고 발견 시 운영요원, 지도자 또는 인근 소방관서(119), 해양수상구조대(122)에 신속하게 신고합니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "스포츠안전교육에 대한 상담을 받으려면 어떻게 해야 하나요?",
#         "ANSWER": "스포츠안전교육에 대한 상담을 받으시려면 02-425-5952로 전화하시면 됩니다."
#     },
#     {
#         "QUESTION": "응급처치 매뉴얼의 무단 전재 및 배포는 가능한가요?",
#         "ANSWER": "응급처치 매뉴얼의 무단 전재 및 배포는 금지되어 있습니다."
#     },
#     {
#         "QUESTION": "스포츠안전재단의 위치는 어디인가요?",
#         "ANSWER": "스포츠안전재단은 서울특별시 송파구 백제고분로 508 제일빌딩(방이동 180-4) 4층에 위치해 있습니다."
#     }
# ]
# ``````json
# [
#     {
#         "QUESTION": "스포츠 안전 교육에 대한 상담을 받으려면 어떻게 해야 하나요?",
#         "ANSWER": "스포츠 안전 교육에 대한 상담을 받으려면 02-425-5952로 전화하시면 됩니다."
#     },
#     {
#         "QUESTION": "스포츠안전재단의 안전사업팀은 어디에 위치해 있나요?",
#         "ANSWER": "스포츠안전재단의 안전사업팀은 서울시 송파구 백제고분로 508 제일빌딩 4층에 위치해 있습니다."
#     },
#     {
#         "QUESTION": "스포츠안전재단의 웹사이트 주소는 무엇인가요?",
#         "ANSWER": "스포츠안전재단의 웹사이트 주소는 www.sportsafety.or.kr입니다."
#     }
# ]
# ```Processing file: /content/drive/MyDrive/3rd project_pdf /응급처치 가이드 (1).pdf
# ```json
# {
#     "QUESTION": "응급처치 매뉴얼이란 무엇인가요?",
#     "ANSWER": "응급처치 매뉴얼은 응급 상황에서 적절한 조치를 취할 수 있도록 안내하는 지침서입니다."
# },
# {
#     "QUESTION": "응급처치 매뉴얼의 목적은 무엇인가요?",
#     "ANSWER": "응급처치 매뉴얼의 목적은 응급 상황에서 신속하고 효과적인 대응을 통해 부상자나 환자의 상태를 안정시키고, 추가적인 손상을 방지하는 것입니다."
# },
# {
#     "QUESTION": "응급처치 매뉴얼은 어떤 상황에서 사용되나요?",
#     "ANSWER": "응급처치 매뉴얼은 사고나 질병으로 인해 즉각적인 조치가 필요한 응급 상황에서 사용됩니다."
# }
# ``````json
# {
#     "QUESTION": "심정지 상황에서 심폐소생술은 어떻게 수행하나요?",
#     "ANSWER": "심정지 상황에서는 즉시 심폐소생술을 시작해야 하며, 가슴 압박과 인공호흡을 번갈아 가며 수행합니다."
# },
# {
#     "QUESTION": "골절 및 염좌가 발생했을 때 부목고정은 어떻게 하나요?",
#     "ANSWER": "골절 및 염좌가 발생했을 때는 부목을 사용하여 손상 부위를 고정시켜 추가적인 손상을 방지합니다."
# },
# {
#     "QUESTION": "출혈이 발생했을 때 지혈을 위해 어떤 조치를 취해야 하나요?",
#     "ANSWER": "출혈이 발생했을 때는 깨끗한 천이나 붕대로 상처 부위를 압박하여 지혈을 시도합니다."
# }
# ``````json
# {
#     "QUESTION": "열사병이 발생했을 때는 어떻게 해야 하나요?",
#     "ANSWER": "열사병이 발생했을 때는 즉시 시원한 장소로 이동시키고, 옷을 느슨하게 하며, 체온을 낮추기 위해 물을 뿌리거나 젖은 수건으로 몸을 닦아줍니다."
# },
# {
#     "QUESTION": "저체온증이 의심될 때는 어떤 조치를 취해야 하나요?",
#     "ANSWER": "저체온증이 의심될 때는 따뜻한 장소로 이동시키고, 젖은 옷을 제거한 후 담요로 몸을 감싸 체온을 유지하도록 합니다."
# },
# {
#     "QUESTION": "천식으로 인한 호흡곤란이 있을 때는 어떻게 해야 하나요?",
#     "ANSWER": "천식으로 인한 호흡곤란이 있을 때는 환자가 편안한 자세를 취하도록 하고, 처방된 흡입기를 사용하여 증상을 완화시킵니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "응급처치의 기본 원칙은 무엇인가요?",
#         "ANSWER": "응급처치의 기본 원칙은 환자의 상태를 신속하게 평가하고, 필요한 경우 즉시 응급처치를 제공하여 생명을 구하고 상태를 안정시키는 것입니다."
#     },
#     {
#         "QUESTION": "응급처치 시 가장 먼저 해야 할 일은 무엇인가요?",
#         "ANSWER": "응급처치 시 가장 먼저 해야 할 일은 주변의 안전을 확인하고, 환자의 의식과 호흡을 평가하는 것입니다."
#     },
#     {
#         "QUESTION": "응급처치 교육의 중요성은 무엇인가요?",
#         "ANSWER": "응급처치 교육은 비상 상황에서 적절한 대처를 통해 생명을 구하고 부상 정도를 최소화할 수 있도록 도와주는 중요한 지식과 기술을 제공합니다."
#     }
# ]
# ``````json
# [
#     {
#         "QUESTION": "스포츠 활동 중 응급상황이 발생했을 때 왜 신속하고 적절한 응급처치가 중요한가요?",
#         "ANSWER": "응급처치를 얼마나 신속하고 적절하게 실시하였는가에 따라 부상자의 삶과 죽음, 일시적 장애와 영구적인 손상이 결정되기 때문에 매우 중요합니다."
#     },
#     {
#         "QUESTION": "응급상황에서의 행동절차 3C는 무엇인가요?",
#         "ANSWER": "응급상황에서의 행동절차 3C는 현장조사(Check), 119 신고(Call), 처치 및 도움(Care)입니다."
#     },
#     {
#         "QUESTION": "응급상황 발생 시 119에 신고할 때 주의해야 할 점은 무엇인가요?",
#         "ANSWER": "즉시 전화하고 필수 정보를 알리며, 질문에 대답하고 전화를 먼저 끊지 않으며 신고 후 지체 없이 처치해야 합니다."
#     }
# ]
# ``````json
# [
#     {
#         "QUESTION": "스포츠 활동 중 응급상황 발생 시 가장 먼저 해야 할 일은 무엇인가요?",
#         "ANSWER": "스포츠 활동 중 응급상황이 발생하면 가장 먼저 119에 신고하여 구급대원이 현장에 빨리 도착할 수 있도록 하는 것이 중요합니다."
#     },
#     {
#         "QUESTION": "응급상황에서 환자의 상태를 확인할 때 어떤 점을 주의 깊게 살펴봐야 하나요?",
#         "ANSWER": "응급상황에서 환자의 상태를 확인할 때는 의식이 있는지, 숨을 쉬는 것이 곤란한지, 가슴이나 목에 통증이 있는지, 이유 없이 땀을 흘리지는 않는지, 피부색이 창백하거나 푸르게 변하지는 않는지를 주의 깊게 살펴봐야 합니다."
#     },
#     {
#         "QUESTION": "응급처치를 할 때 환자의 분비물과 접촉을 피하기 위해 어떤 장비를 사용해야 하나요?",
#         "ANSWER": "응급처치를 할 때 환자의 분비물과 직접적인 접촉을 피하기 위해 소독장갑이나 보호 장비를 사용해야 합니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "전봇대의 고유번호는 어떤 상황에서 유용하게 사용될 수 있나요?",
#     "ANSWER": "전봇대의 고유번호는 낯선 곳에서 자신의 위치를 파악할 때 유용하게 사용될 수 있습니다."
# },
# {
#     "QUESTION": "승강기 사고 발생 시 소방관이 위치를 파악하는 방법은 무엇인가요?",
#     "ANSWER": "승강기 사고 발생 시 소방관은 내부 층수 버튼 옆에 있는 승강기 고유번호와 QR 코드를 통해 위치를 파악할 수 있습니다."
# },
# {
#     "QUESTION": "승강기 고유번호는 어떤 상황에서 확인해야 하나요?",
#     "ANSWER": "승강기 고유번호는 승강기 사고 발생 시 확인해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "응급처치를 시작하기 전에 환자에게 어떤 절차를 따라야 하나요?",
#     "ANSWER": "응급처치를 시작하기 전에 환자에게 사전 동의를 구해야 하며, 자신의 이름, 신분 및 응급처치 교육경력을 밝히고 앞으로 행할 응급처치에 대한 설명을 해야 합니다."
# },
# {
#     "QUESTION": "환자가 의식이 없을 때 응급처치를 어떻게 진행해야 하나요?",
#     "ANSWER": "환자가 의식이 없거나 반응을 할 수 없는 경우, 묵시적 동의로 판단하고 응급처치를 시행합니다."
# },
# {
#     "QUESTION": "출혈이 발생했을 때 어떤 응급처치를 해야 하나요?",
#     "ANSWER": "출혈이 발생했을 때는 피가 흐르는 것을 막기 위한 지혈을 해야 합니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "기도를 방해하거나 폐쇄를 일으킬 수 있는 손상에는 어떤 것들이 있나요?",
#         "ANSWER": "기도를 방해하거나 폐쇄를 일으킬 수 있는 손상에는 흡인성 손상, 흉곽 손상, 긴장성 기흉, 질식을 초래하거나 질식 상태에 있는 상악이나 안면의 손상이 있습니다."
#     },
#     {
#         "QUESTION": "즉각적인 지혈이 필요한 경우는 어떤 상황인가요?",
#         "ANSWER": "즉각적인 지혈이 필요한 경우는 즉각적 지혈을 요하는 모든 출혈 상황입니다."
#     },
#     {
#         "QUESTION": "응급 처치 시 우선 순위는 어떻게 되나요?",
#         "ANSWER": "응급 처치 시 우선 순위는 즉각적인 처치를 요하는 환자와 긴급 수술을 요하는 환자가 1순위이며, 수술이 필요하지만 지연이 가능한 환자가 2순위입니다."
#     }
# ]
# ``````json
# [
#     {
#         "QUESTION": "선한 사마리아인법이란 무엇인가요?",
#         "ANSWER": "선한 사마리아인법은 고통 받는 사람을 기꺼이 도와주기 위하여, 즉 도덕적 의무를 이행하다가 예기치 않은 피해가 발생하더라도 고의나 중대한 과실이 없을 경우에는 민, 형사상 책임을 면제하는 것을 의미합니다."
#     },
#     {
#         "QUESTION": "선한 사마리아인법이 적용되기 위한 조건은 무엇인가요?",
#         "ANSWER": "선한 사마리아인법이 적용되기 위해서는 생명이 위급한 상황에서 행동을 하고, 올바른 신념에 따라 행동하며, 보상을 바라지 않고 행동하고, 악의에 찬 행위 또는 지나친 과실을 범하지 않아야 합니다."
#     },
#     {
#         "QUESTION": "응급의료종사자가 아닌 사람이 응급처치를 제공할 때 책임이 면제되는 경우는 언제인가요?",
#         "ANSWER": "응급의료종사자가 아닌 자가 응급처치를 제공하여 발생한 재산상 손해와 사상에 대하여 고의 또는 중대한 과실이 없는 경우 그 행위자는 민사 책임과 상해에 대한 형사 책임을 지지 아니하고 사망에 대한 형사 책임은 감면됩니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "심정지 상황에서 가장 먼저 해야 할 응급처치는 무엇인가요?",
#     "ANSWER": "심정지 상황에서는 즉시 심폐소생술(CPR)을 시작하는 것이 가장 중요합니다."
# },
# {
#     "QUESTION": "심정지 환자에게 심폐소생술을 시행할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "심폐소생술을 시행할 때는 가슴 압박의 깊이와 속도를 적절히 유지하며, 인공호흡을 병행하는 것이 중요합니다."
# },
# {
#     "QUESTION": "심정지 상황에서 자동심장충격기(AED)를 사용하는 방법은 무엇인가요?",
#     "ANSWER": "자동심장충격기(AED)는 전원을 켜고 음성 안내에 따라 패드를 부착한 후, 지시에 따라 충격 버튼을 눌러 사용합니다."
# }
# ``````json
# {
#     "QUESTION": "심정지 환자를 발견했을 때 가장 먼저 해야 할 일은 무엇인가요?",
#     "ANSWER": "심정지 환자를 발견하면 즉시 의료인에게 도움을 청해야 하며 심폐소생술을 실시해야 합니다."
# },
# {
#     "QUESTION": "심정지 전조 증상 중 하나로 나타날 수 있는 증상은 무엇인가요?",
#     "ANSWER": "심정지 전조 증상으로는 식은땀이 나고, 호흡곤란이 발생하며, 구토와 메스꺼움을 호소할 수 있습니다."
# },
# {
#     "QUESTION": "심정지 시 심폐소생술이 중요한 이유는 무엇인가요?",
#     "ANSWER": "심정지 환자가 발견된 즉시 심폐소생술이 시행된 경우에는 심폐소생술이 시행되지 않은 경우에 비하여 일반적으로 생존율이 3배 정도 높기 때문입니다."
# }
# ``````json
# {
#     "QUESTION": "심폐소생술을 시작하기 전에 환자에게 어떤 반응을 확인해야 하나요?",
#     "ANSWER": "환자의 어깨를 가볍게 두드리며 큰소리로 '괜찮으세요?'라고 물어보며 반응을 확인하고, 특정인을 지목하여 119신고를 요청해야 합니다."
# },
# {
#     "QUESTION": "심폐소생술 중 가슴 압박의 깊이와 속도는 어떻게 해야 하나요?",
#     "ANSWER": "가슴 압박의 깊이는 약 5cm로 하고, 분당 100~120회의 속도로 압박해야 합니다."
# },
# {
#     "QUESTION": "인공호흡을 할 때 환자의 기도를 어떻게 유지해야 하나요?",
#     "ANSWER": "한손으로 환자의 머리를 젖히고, 다른 손으로 턱 끝을 들어 올려 기도를 유지해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "자동심장충격기(AED)를 사용할 때 첫 번째 단계는 무엇인가요?",
#     "ANSWER": "자동심장충격기(AED)를 사용할 때 첫 번째 단계는 전원을 켜는 것입니다."
# },
# {
#     "QUESTION": "심장리듬 분석 중에 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "심장리듬 분석 중에는 '접촉금지'라는 음성안내에 따라 환자에게서 떨어져야 하며, 분석이 끝나면 약 8초의 충전시간이 소요됩니다."
# },
# {
#     "QUESTION": "자동심장충격기(AED) 사용 시 패드를 부착할 위치는 어디인가요?",
#     "ANSWER": "패드는 하나는 오른쪽 빗장뼈 아래, 나머지 하나는 왼쪽 겨드랑이 아래에 위치하도록 부착합니다."
# }
# ``````json
# {
#     "QUESTION": "자동심장충격기(AED)의 위치를 어떻게 찾을 수 있나요?",
#     "ANSWER": "휴대폰 어플리케이션인 '응급의료정보제공'을 다운받아 '제세동기 찾기' 메뉴를 통해 현 위치를 중심으로 자동심장충격기가 설치된 위치를 알 수 있습니다."
# },
# {
#     "QUESTION": "스포츠 활동 전에 자동심장충격기(AED) 위치를 미리 확인해야 하는 이유는 무엇인가요?",
#     "ANSWER": "응급상황 시 신속히 자동심장충격기를 사용할 수 있도록 하기 위해 스포츠 활동 전에 미리 위치를 확인하는 것이 중요합니다."
# },
# {
#     "QUESTION": "응급의료정보제공 어플리케이션을 통해 제공되는 정보는 무엇인가요?",
#     "ANSWER": "응급의료정보제공 어플리케이션은 자동심장충격기(AED)의 위치를 찾을 수 있는 정보를 제공합니다."
# }
# ``````json
# {
#     "QUESTION": "근골격계 손상 시 응급처치는 어떻게 해야 하나요?",
#     "ANSWER": "근골격계 손상 시에는 부상 부위를 고정하고, 가능한 한 움직이지 않도록 하며, 즉시 의료기관을 방문하여 전문적인 치료를 받는 것이 중요합니다."
# },
# {
#     "QUESTION": "근골격계 손상 예방을 위해 어떤 조치를 취할 수 있나요?",
#     "ANSWER": "근골격계 손상을 예방하기 위해서는 규칙적인 운동과 스트레칭을 통해 근육과 관절을 강화하고, 적절한 보호 장비를 착용하는 것이 중요합니다."
# },
# {
#     "QUESTION": "근골격계 손상 후 회복을 돕기 위한 방법은 무엇인가요?",
#     "ANSWER": "근골격계 손상 후 회복을 돕기 위해서는 적절한 재활 운동과 물리치료를 통해 손상 부위의 기능을 회복시키고, 전문 의료진의 지시에 따라 치료 계획을 따르는 것이 중요합니다."
# }
# ``````json
# {
#     "QUESTION": "염좌가 발생했을 때 나타나는 증상은 무엇인가요?",
#     "ANSWER": "염좌가 발생한 부위는 붓고 빨개지며 통증이 생기고, 누르면 아프며 멍이 들기도 하고 관절이 경직되어 운동성이 감소합니다."
# },
# {
#     "QUESTION": "단순 골절과 복잡 골절의 차이점은 무엇인가요?",
#     "ANSWER": "단순 골절은 골절 부위가 붓거나 저리고 아프며 제한적으로 움직일 수 있는 반면, 복잡 골절은 부러진 뼈의 끝이 피부를 뚫고 나와 심한 출혈이 동반될 수 있습니다."
# },
# {
#     "QUESTION": "스포츠 상황에서 근골격계 손상을 입었을 때 왜 적절한 처치가 중요한가요?",
#     "ANSWER": "근골격계 손상은 적절한 처치가 이루어지지 않으면 2차적인 손상을 가져올 수 있으며, 영구적인 손상이나 장애를 초래할 수 있기 때문에 손상을 정확히 파악하고 적절하게 대처해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "R.I.C.E. 응급처치에서 '안정'은 무엇을 의미하나요?",
#     "ANSWER": "R.I.C.E. 응급처치에서 '안정'은 상처부위를 되도록 움직이지 않도록 하고 경우에 따라 고정시키는 것을 의미합니다."
# },
# {
#     "QUESTION": "얼음찜질은 언제까지, 얼마나 자주 해야 하나요?",
#     "ANSWER": "얼음찜질은 다친 후 약 48시간까지 2~3시간마다 20~30분씩 실시해야 합니다."
# },
# {
#     "QUESTION": "상처부위를 심장보다 높게 올리는 이유는 무엇인가요?",
#     "ANSWER": "상처부위를 심장보다 높게 올리면 다친 부위로 혈액이 덜 가게 되어 내부 출혈이 억제되고 부종이 줄어듭니다."
# }
# ``````json
# {
#     "QUESTION": "골절된 부위를 옮겨야 할 때 어떤 조치를 취해야 하나요?",
#     "ANSWER": "골절 부위가 2차 손상을 일으키지 않도록 반드시 부목을 댄 후 운반해야 합니다."
# },
# {
#     "QUESTION": "부목을 사용할 수 없는 경우에는 어떻게 해야 하나요?",
#     "ANSWER": "부목을 댈 여유가 없거나 긴급히 옮겨야 할 경우에는 한 손으로 골절된 부위의 위쪽을, 다른 손으로 그 아래쪽을 보호하여 환자를 운반합니다."
# },
# {
#     "QUESTION": "전문 구조요원의 도움이 절대적으로 필요한 경우는 언제인가요?",
#     "ANSWER": "과다한 출혈 또는 머리, 목, 척추의 부상이나 다리 및 대퇴부 등의 골절로 환자 이송이 어려울 경우 전문 구조요원의 도움이 절대적으로 필요합니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "부목고정의 목적은 무엇인가요?",
#         "ANSWER": "부목고정의 목적은 상처 부위의 부러진 뼈에 의해 생길 수 있는 추가적인 손상을 방지하거나, 복잡 골절로 악화되는 것을 방지하고, 뼈에 의해 혈관이 압박되어 골절 원위부의 혈액순환이 차단되는 것을 방지하는 것입니다."
#     },
#     {
#         "QUESTION": "골절이 확실하지 않더라도 손상이 의심될 때는 어떻게 해야 하나요?",
#         "ANSWER": "골절이 확실하지 않더라도 손상이 의심될 때는 부목을 이용하여 고정해야 합니다."
#     },
#     {
#         "QUESTION": "부목을 댄 후에 주기적으로 확인해야 하는 것은 무엇인가요?",
#         "ANSWER": "부목을 댄 후에도 골절 원위부에서 맥박, 감각, 운동기능을 주기적으로 확인해야 합니다."
#     }
# ]
# ``````json
# [
#     {
#         "QUESTION": "골절된 부위에 부목을 고정할 때 어떤 길이의 부목을 사용해야 하나요?",
#         "ANSWER": "부목은 골절된 뼈의 양쪽 관절 너머까지 걸칠 만큼 긴 것을 사용해야 합니다."
#     },
#     {
#         "QUESTION": "부목을 사용할 때 피부 손상을 방지하기 위해 어떤 조치를 취해야 하나요?",
#         "ANSWER": "부목 안쪽에 헝겊을 고여서 피부가 상하지 않도록 해야 하며, 가능한 가볍고 단단한 것을 사용해야 합니다."
#     },
#     {
#         "QUESTION": "적당한 부목이 없을 경우 어떤 대체물을 사용할 수 있나요?",
#         "ANSWER": "적당한 부목이 없을 경우 환자의 전신 또는 일부분을 신문지 뭉치, 잡지, 담요, 베개 등을 대응 부목으로 사용할 수 있습니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "근육경련이 발생했을 때 어떻게 응급처치를 해야 하나요?",
#     "ANSWER": "환자를 눕혀 편안한 자세를 유지시키며 안정을 취하도록 하고, 경련 부위가 종아리 근육이거나 뒤쪽 허벅지인 경우 다리를 쭉 핀 상태에서 발목을 몸 쪽으로 서서히 당겨줍니다. 경련 부위가 허벅지 근육이면 다리부분을 뒤로 굽히는 등 근육경련이 발생한 근육을 반대편으로 당겨줍니다."
# },
# {
#     "QUESTION": "근육경련을 예방하기 위해서는 어떤 방법이 좋은가요?",
#     "ANSWER": "근육경련을 예방하기 위해서는 평소 스트레칭을 꾸준히 실시하고, 충분한 수분섭취를 하는 것이 좋습니다."
# },
# {
#     "QUESTION": "근육경련이란 무엇인가요?",
#     "ANSWER": "근육경련이란 근육의 일부가 저절로 통증을 동반하면서 과도하게 수축되는 것을 말합니다."
# }
# ``````json
# {
#     "QUESTION": "출혈이 발생했을 때 가장 먼저 해야 할 응급처치는 무엇인가요?",
#     "ANSWER": "출혈이 발생했을 때 가장 먼저 해야 할 응급처치는 출혈 부위를 압박하여 지혈하는 것입니다."
# },
# {
#     "QUESTION": "출혈 부위를 압박할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "출혈 부위를 압박할 때는 깨끗한 천이나 거즈를 사용하여 직접 압박하고, 압박이 충분하지 않으면 추가로 압박을 가해야 합니다."
# },
# {
#     "QUESTION": "출혈이 심할 경우 어떻게 대처해야 하나요?",
#     "ANSWER": "출혈이 심할 경우 즉시 응급 의료 서비스를 요청하고, 출혈 부위를 계속해서 압박하여 지혈을 시도해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "출혈이 심한 경우 나타날 수 있는 증상은 무엇인가요?",
#     "ANSWER": "출혈이 심한 경우 호흡과 맥박이 빨라지고 호흡 곤란이 발생할 수 있으며, 피부가 창백해지고 체온이 떨어질 수 있습니다. 또한 갈증을 느끼면서 동공이 확대되며 구토가 발생할 수도 있습니다."
# },
# {
#     "QUESTION": "출혈이란 무엇을 의미하나요?",
#     "ANSWER": "출혈이란 혈관의 손상에 의해 혈액이 혈관 밖으로 나오는 현상을 의미합니다."
# },
# {
#     "QUESTION": "스포츠 활동 중 출혈이 발생했을 때 어떤 응급처치가 필요한가요?",
#     "ANSWER": "스포츠 활동 중 출혈이 발생했을 때는 작은 상처라도 2차 감염의 위험성이 있으므로 소독과 지혈 등의 적절한 처치를 해야 하며, 심한 출혈이 있을 경우에는 상처 부위나 크기에 따른 응급처치가 필요합니다."
# }
# ``````json
# {
#     "QUESTION": "직접 압박 지혈은 어떻게 수행하나요?",
#     "ANSWER": "직접 압박 지혈은 출혈 부위를 소독거즈로 덮은 후 손으로 압박하여 출혈을 멈추는 방법입니다."
# },
# {
#     "QUESTION": "출혈이 멈추지 않을 때는 어떻게 해야 하나요?",
#     "ANSWER": "출혈이 멈추지 않으면 더 세게 압박하고, 응고를 위해 적어도 10분 이상 상처를 압박해야 합니다."
# },
# {
#     "QUESTION": "지혈대는 언제 사용해야 하나요?",
#     "ANSWER": "지혈대는 직접 압박 지혈과 동맥점 압박 지혈로 출혈을 멈출 수 없는 경우에 사용해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "직접 압박으로 지혈되지 않는 경우 어떤 방법을 사용하나요?",
#     "ANSWER": "직접 압박으로 지혈되지 않는 경우 해당 동맥과 가까운 지혈점을 압박함으로써 심한 출혈을 억제하는 방법을 사용합니다."
# },
# {
#     "QUESTION": "손의 출혈이 있을 때 어떤 동맥을 압박해야 하나요?",
#     "ANSWER": "손의 출혈이 있을 때는 요골동맥을 압박해야 합니다."
# },
# {
#     "QUESTION": "하지 출혈 시 어떤 동맥을 압박해야 하나요?",
#     "ANSWER": "하지 출혈 시에는 대퇴동맥을 압박해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "지혈대는 언제 사용해야 하나요?",
#     "ANSWER": "지혈대는 직접 압박과 혈관 압박으로도 출혈을 멈출 수 없을 때에 사용되는 방법입니다."
# },
# {
#     "QUESTION": "지혈대를 사용할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "지혈대를 사용할 때는 신경이나 혈관에 손상을 줄 수 있으며 팔이나 다리에 괴사를 초래할 수 있으므로 일정한 시간마다 지혈대를 풀어서 괴사를 방지하는 것이 중요합니다."
# },
# {
#     "QUESTION": "지혈대를 사용한 후에는 어떻게 해야 하나요?",
#     "ANSWER": "지혈대를 맨 후 시간이 오래 경과하지 않도록 하고 신속히 병원으로 이송해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "충격에 의해 신체 손상을 입었을 때 가장 먼저 해야 할 응급처치는 무엇인가요?",
#     "ANSWER": "충격에 의해 신체 손상을 입었을 때는 즉시 손상 부위를 확인하고, 출혈이 있는 경우에는 깨끗한 천으로 압박하여 지혈을 시도합니다."
# },
# {
#     "QUESTION": "응급처치 시 주의해야 할 사항은 무엇인가요?",
#     "ANSWER": "응급처치 시에는 손상 부위를 과도하게 움직이지 않도록 주의하고, 가능한 한 빨리 전문 의료진의 도움을 받는 것이 중요합니다."
# },
# {
#     "QUESTION": "신체 손상 후 응급처치가 필요한 이유는 무엇인가요?",
#     "ANSWER": "신체 손상 후 응급처치는 추가적인 손상을 방지하고, 회복 시간을 단축시키며, 생명을 구할 수 있는 중요한 단계입니다."
# }
# ``````json
# {
#     "QUESTION": "뇌진탕이 발생했을 때 의식이 없는 경우 어떻게 해야 하나요?",
#     "ANSWER": "환자의 의식 여부를 확인한 후 의식이 없다면 즉시 심폐소생술을 실시해야 합니다."
# },
# {
#     "QUESTION": "뇌진탕으로 인해 부딪힌 부분이 부었을 때는 어떻게 처치해야 하나요?",
#     "ANSWER": "부딪힌 부분이 부었을 경우 차가운 찜질을 해주고 눕힌 상태에서 상체만 일으켜 앉힌 후 넘어지지 않게 상체를 기대게 합니다."
# },
# {
#     "QUESTION": "뇌진탕 후 어떤 증상이 나타나면 병원에 가서 정밀검사를 받아야 하나요?",
#     "ANSWER": "안정을 취한 뒤에도 기력저하, 기억상실 등의 증세를 보이면 병원에 가서 정밀검사를 받아야 합니다."
# }
# ``````json
# {
#     "QUESTION": "치아가 흔들릴 경우 어떻게 응급처치를 해야 하나요?",
#     "ANSWER": "치아가 흔들릴 경우에는 잇몸을 깨끗한 천 등으로 눌러 지혈하고, 통증과 흔들림이 지속된다면 최대한 빠른 시간내에 병원을 내원하여 진료를 받아야 합니다."
# },
# {
#     "QUESTION": "치아가 빠졌을 때 어떻게 응급처치를 해야 하나요?",
#     "ANSWER": "치아가 빠졌을 경우 치아의 뿌리 부분인 치근을 만지지 말고 치아의 머리 부분인 치관을 잡아 흐르는 찬물에 10초 동안 헹궈준 후 빠진 치아자리에 밀어 넣고 신속히 병원으로 가야 합니다. 치아를 밀어 넣지 못했을 경우에는 우유나 식염수, 수돗물에 담가 치아를 마르지 않게 한 후 병원으로 가는 것이 좋습니다."
# },
# {
#     "QUESTION": "치아 손상이 발생했을 때 왜 1시간 이내로 병원을 찾아야 하나요?",
#     "ANSWER": "치아 손상이 발생했을 때 1시간 이내로 병원을 찾아야 하는 이유는 치아뿌리의 치근막 세포가 정상적으로 살아있다면 인공치아 대신 자신의 치아를 살려 치료할 수 있기 때문입니다."
# }
# ``````json
# {
#     "QUESTION": "두개골 골절 시 어떤 증상이 나타날 수 있나요?",
#     "ANSWER": "두개골 골절 시 극심한 통증과 머리 모양의 변형 또는 상처의 흔적이 생기며, 두피가 안쪽으로 들어가거나 말랑말랑한 혹이 생기고 머리, 얼굴 모양이 변형될 수 있습니다."
# },
# {
#     "QUESTION": "두개골 골절 환자를 응급처치할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "환자를 무리하게 옮기거나 처치하지 않으며, 의식이 없는 경우 환자를 눕히고 머리와 어깨를 들어서 부드러운 것으로 받치고, 귀나 코에서 흐르는 뇌척수액은 절대로 막거나 닦아내지 않고 흘러내리게 합니다."
# },
# {
#     "QUESTION": "두개골 골절 시 현장에서 제거하지 말아야 할 것은 무엇인가요?",
#     "ANSWER": "두개골에 박힌 이물질은 절대 현장에서 제거하지 않습니다."
# }
# ``````json
# {
#     "QUESTION": "온도변화로 인한 신체손상에는 어떤 종류가 있나요?",
#     "ANSWER": "온도변화로 인한 신체손상에는 저체온증과 열사병이 포함됩니다."
# },
# {
#     "QUESTION": "저체온증이 발생했을 때 응급처치는 어떻게 해야 하나요?",
#     "ANSWER": "저체온증이 발생했을 때는 따뜻한 장소로 옮기고, 젖은 옷을 제거한 후 따뜻한 담요로 몸을 감싸 체온을 유지해야 합니다."
# },
# {
#     "QUESTION": "열사병이 의심될 때는 어떤 조치를 취해야 하나요?",
#     "ANSWER": "열사병이 의심될 때는 즉시 시원한 장소로 옮기고, 옷을 느슨하게 하며, 물을 마시게 하여 체온을 낮추는 것이 중요합니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "스포츠 활동 중 열사병이 발생했을 때 어떻게 대처해야 하나요?",
#         "ANSWER": "열사병이 발생했을 때는 즉시 시원한 장소로 이동하여 몸을 식히고, 물을 충분히 마시며, 필요시 의료진의 도움을 받아야 합니다."
#     },
#     {
#         "QUESTION": "저체온증이 의심될 때 어떤 조치를 취해야 하나요?",
#         "ANSWER": "저체온증이 의심될 때는 따뜻한 장소로 이동하여 젖은 옷을 제거하고, 담요로 몸을 감싸 체온을 유지하며, 따뜻한 음료를 제공하여 체온을 회복시켜야 합니다."
#     },
#     {
#         "QUESTION": "동상이 발생했을 때는 어떻게 해야 하나요?",
#         "ANSWER": "동상이 발생했을 때는 동상 부위를 따뜻한 물에 담가 서서히 녹이고, 문지르지 않도록 주의하며, 심한 경우에는 즉시 의료진의 도움을 받아야 합니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "화상을 입었을 때 피부의 열기를 줄이기 위해 어떻게 해야 하나요?",
#     "ANSWER": "피부의 열기를 줄이기 위해 흐르는 물에 15분 이상 환부를 차게 합니다. 차가운 수돗물이나 얼음을 넣은 비닐봉투 등을 활용해도 좋습니다."
# },
# {
#     "QUESTION": "화상 부위의 옷을 벗길 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "화상 부위의 옷을 벗길 때는 무리하게 옷을 벗겨 물집이 벗겨지거나 터트리지 않도록 조심스럽게 벗겨야 합니다."
# },
# {
#     "QUESTION": "경미한 화상을 제외하고는 어떻게 해야 하나요?",
#     "ANSWER": "경미한 화상을 제외하고는 환자를 병원으로 후송해야 합니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "화상 부위에 옷이 달라붙었을 때는 어떻게 해야 하나요?",
#         "ANSWER": "화상 부위에 옷이 달라붙었다면 옷을 벗기다 피부에 손상을 줄 수 있으니 가위를 이용해 옷을 찢어야 합니다."
#     },
#     {
#         "QUESTION": "화상 부위에 얼음을 대면 안 되는 이유는 무엇인가요?",
#         "ANSWER": "화상 부위에 얼음을 대면 혈관 수축으로 염증성 물집이 생성되어 증상을 더욱 악화시킬 수 있습니다."
#     },
#     {
#         "QUESTION": "화상 치료 후 상처 부위를 자외선으로부터 보호하는 방법은 무엇인가요?",
#         "ANSWER": "상처가 자외선에 노출되면 피부 변색을 일으킬 수 있으므로 외출할 때에는 자외선차단제를 반드시 발라주고, 상처부위를 가리는 부드러운 면 소재의 옷을 입는 것이 좋습니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "열사병이 발생했을 때 나타날 수 있는 증상은 무엇인가요?",
#     "ANSWER": "열사병이 발생했을 때 체온이 40도까지 상승할 수 있으며, 땀을 흘리지 않거나 의식 및 행동의 변화(가벼운 혼동, 지남력상실, 무의식)가 나타날 수 있습니다."
# },
# {
#     "QUESTION": "열사병 환자에게 가장 중요한 응급처치 방법은 무엇인가요?",
#     "ANSWER": "열사병 환자의 경우 몸을 식혀주고 수분을 섭취하는 것이 중요합니다. 즉시 환자를 시원한 곳으로 옮기면 체온 조절 중추의 기능이 곧 회복되어 체온이 신속하게 떨어집니다."
# },
# {
#     "QUESTION": "열사병 환자의 의식이 있는 경우 어떻게 수분을 보충해야 하나요?",
#     "ANSWER": "환자의 의식이 있는 경우 시원한 물을 천천히 먹도록 하여 모자라는 수분을 보충합니다."
# }
# ``````json
# {
#     "QUESTION": "일사병이 발생했을 때 응급처치 방법은 무엇인가요?",
#     "ANSWER": "일사병이 발생했을 때는 환자를 그늘진 시원한 장소로 옮기고 옷을 벗긴 후에 편안한 자세를 취하게 하며, 다리를 편 상태로 20~30cm 정도 높여줍니다. 입으로 소금이 들어간 찬 물 또는 이온음료를 마시게 하고, 찬물을 묻힌 스펀지로 몸을 적신 후에 부채질을 해줍니다. 30분 이내에 증상이 회복되지 않으면 병원으로 이송합니다."
# },
# {
#     "QUESTION": "일사병 발생 시 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "일사병 발생 시 알약 형태의 소금덩어리는 위를 자극하고, 메스꺼움과 구토를 유발할 수 있으므로 주지 않는 것이 좋습니다. 또한, 술 또는 카페인은 체온 조절기능을 방해하므로 이것이 들어 있는 음료수는 주지 않는 것이 좋습니다."
# },
# {
#     "QUESTION": "열사병과 일사병의 차이점은 무엇인가요?",
#     "ANSWER": "열사병은 고열 또는 의식 변화가 발생할 수 있는 반면, 일사병은 체온과 의식 변화 측면에서 대부분 정상처럼 보이는 경우가 많습니다."
# }
# ``````json
# {
#     "QUESTION": "동상이란 무엇인가요?",
#     "ANSWER": "동상은 신체 조직의 일부가 언 상태를 의미하며, 주로 스포츠 활동 시 저온에 노출된 신체 부위에 발생합니다."
# },
# {
#     "QUESTION": "동상이 발생했을 때 응급처치 방법은 무엇인가요?",
#     "ANSWER": "동상 부위를 매우 조심스럽게 다루고, 추운 곳에서 벗어나 따뜻한 곳으로 이동합니다. 젖은 옷은 마른 옷으로 갈아입고, 손상부위를 따뜻한 담요 등으로 감싸면서 서서히 따뜻하게 해줍니다. 동상 부위를 37~40도 정도의 물에 담그고 따뜻하게 하며, 물속에 넣어둔 상태에서 동상 부위가 다시 붉은 색으로 변하고 따뜻해질 때까지 기다립니다."
# },
# {
#     "QUESTION": "동상 부위를 문지르면 안 되는 이유는 무엇인가요?",
#     "ANSWER": "동상 부위를 문지르면 손상된 조직이 더 악화될 수 있기 때문에 절대 문지르지 않아야 합니다."
# }
# ``````json
# {
#     "QUESTION": "저체온증이 발생했을 때 가장 먼저 해야 할 일은 무엇인가요?",
#     "ANSWER": "저체온증이 발생했을 때 가장 먼저 해야 할 일은 즉시 119에 신고하는 것입니다."
# },
# {
#     "QUESTION": "저체온증 환자를 따뜻하게 하기 위해 어떤 조치를 취해야 하나요?",
#     "ANSWER": "저체온증 환자를 따뜻하게 하기 위해 젖은 옷을 벗기고 마른 옷으로 갈아입혀 열손실을 방지하고, 환자의 머리를 찬 공기로부터 보호합니다."
# },
# {
#     "QUESTION": "저체온증 환자에게 급속 가온치료를 하면 안 되는 이유는 무엇인가요?",
#     "ANSWER": "저체온증 환자에게 급속 가온치료를 하면 말초의 차가운 혈액이 순환되어 심정지를 일으킬 수 있기 때문에 하지 않습니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "응급처치가 필요한 질환에는 어떤 것들이 있나요?",
#         "ANSWER": "응급처치가 필요한 질환에는 화상, 벌에 쏘임, 골절 등이 있습니다."
#     },
#     {
#         "QUESTION": "응급처치 시 주의해야 할 점은 무엇인가요?",
#         "ANSWER": "응급처치 시에는 상처 부위를 깨끗하게 유지하고, 가능한 경우 멸균 처리된 거즈를 사용하여 감염을 방지해야 합니다."
#     },
#     {
#         "QUESTION": "응급처치의 목적은 무엇인가요?",
#         "ANSWER": "응급처치의 목적은 부상이나 질환으로 인한 추가적인 손상을 방지하고, 환자의 상태를 안정화시키는 것입니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "뇌졸중이 발생했을 때 어떤 증상이 나타날 수 있나요?",
#     "ANSWER": "뇌졸중이 발생하면 얼굴이 한쪽으로 일그러지고, 한쪽 팔의 감각이 없어지며, 말이 새고 말하는 데 어려움이 생길 수 있습니다."
# },
# {
#     "QUESTION": "뇌졸중이 의심될 때 가장 먼저 해야 할 조치는 무엇인가요?",
#     "ANSWER": "뇌졸중이 의심될 때는 즉시 119에 신고하여 최대한 빨리 병원에 도착하도록 조치를 취해야 합니다."
# },
# {
#     "QUESTION": "뇌졸중의 위험성이 증가하는 이유는 무엇인가요?",
#     "ANSWER": "스포츠 참여 인구가 노령화되면서 뇌졸중의 위험성이 증가하고 있습니다."
# }
# ``````json
# {
#     "QUESTION": "뇌졸중 환자를 발견했을 때 가장 먼저 해야 할 일은 무엇인가요?",
#     "ANSWER": "뇌졸중 환자를 발견하면 즉시 119에 신고한 뒤, 사고가 난 시간을 확인하고 환자의 상태를 관찰해야 합니다."
# },
# {
#     "QUESTION": "뇌졸중 환자에게 약이나 물을 먹이면 안 되는 이유는 무엇인가요?",
#     "ANSWER": "뇌졸중 시에는 뇌가 멈춰 기침을 할 수 없기 때문에 약이나 물을 먹이는 행위는 환자를 사망에 이르게 할 수 있습니다."
# },
# {
#     "QUESTION": "뇌졸중 환자를 발견했을 때 피해야 할 행동은 무엇인가요?",
#     "ANSWER": "뇌졸중 환자를 발견했을 때 몸을 흔들거나 얼굴을 툭툭 치지 말고, 바늘로 손을 따는 행위를 하지 말아야 합니다."
# }
# ``````json
# {
#     "QUESTION": "천식 환자가 스포츠 활동을 할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "천식 환자는 기관지의 문제로 호흡이 어려워질 수 있으므로 갑작스럽고 격렬한 활동을 피하는 것이 좋습니다."
# },
# {
#     "QUESTION": "천식으로 인한 응급상황에 대비하기 위해 현장에 비치해야 할 것은 무엇인가요?",
#     "ANSWER": "천식 환자들이 언제든 사용할 수 있도록 응급용 기관지 확장제를 현장에 비치하는 것이 좋습니다."
# },
# {
#     "QUESTION": "천식의 주요 증상은 무엇인가요?",
#     "ANSWER": "천식의 주요 증상은 호흡곤란, 기침, 천명(쌕쌕거림)입니다."
# }
# ``````json
# {
#     "QUESTION": "당뇨병 환자가 저혈당 쇼크를 예방하기 위해 운동 시 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "당뇨병 환자는 과도한 운동을 피하고, 공복 상태에서 운동하지 않도록 주의해야 합니다. 운동 전 식사와 컨디션을 체크하고 틈틈이 간식을 섭취하는 것이 좋습니다."
# },
# {
#     "QUESTION": "당뇨병 환자에게 적당한 운동이 왜 중요한가요?",
#     "ANSWER": "당뇨병 환자의 적당한 운동은 비만을 예방하고 칼로리를 소모시키며, 혈당을 떨어뜨리고 스트레스와 피로를 해소하는 데 효과적입니다."
# },
# {
#     "QUESTION": "저혈당 쇼크의 위험 요인에는 어떤 것들이 있나요?",
#     "ANSWER": "저혈당 쇼크의 위험 요인으로는 과도한 운동과 공복 상태에서의 운동이 있습니다."
# }
# ``````json
# {
#     "QUESTION": "저혈당 쇼크가 발생했을 때 의식이 있는 경우 어떻게 응급처치를 해야 하나요?",
#     "ANSWER": "의식이 있는 경우 빨리 흡수되어 혈당을 올릴 수 있는 당질음식인 설탕물이나 꿀, 초콜릿, 각설탕 등을 섭취하도록 한 후, 운동을 멈추고 휴식하게 합니다."
# },
# {
#     "QUESTION": "저혈당 쇼크가 발생했을 때 의식이 없는 경우 어떻게 응급처치를 해야 하나요?",
#     "ANSWER": "의식이 없는 경우 무리하게 음식물을 먹이려고 하면 음식물이 기도로 넘어가 호흡곤란이나 폐렴을 유발할 수 있으므로 즉시 병원으로 옮겨서 포도당 주사를 맞도록 합니다."
# },
# {
#     "QUESTION": "길가에 쓰러져 있는 사람을 발견했을 때 당뇨병 환자인지 확인하는 방법은 무엇인가요?",
#     "ANSWER": "길가에 쓰러져 있는 사람을 발견했을 때 당뇨병 환자인지 의심해보고 '저는 당뇨병이 있습니다'라는 인식표가 있는지 확인해 봅니다."
# }
# ``````json
# {
#     "QUESTION": "스포츠 현장에서 발생하는 재난 사고에 대한 일반적인 대응 절차는 무엇인가요?",
#     "ANSWER": "스포츠 현장에서 발생하는 재난 사고에 대한 대응 절차는 사고의 종류에 따라 다르며, 각 사고에 맞는 적절한 응급처치와 안전 조치를 취하는 것이 중요합니다."
# },
# {
#     "QUESTION": "스포츠 현장에서 발생할 수 있는 골절 사고에 대한 응급처치는 어떻게 해야 하나요?",
#     "ANSWER": "스포츠 현장에서 골절 사고가 발생했을 때는 부러진 뼈가 신경, 혈관, 근육을 손상하지 않도록 주의하며, 부상자를 가능한 한 움직이지 않게 하고, 전문 의료진의 도움을 받을 때까지 안정시킵니다."
# },
# {
#     "QUESTION": "스포츠 현장에서 화상 사고가 발생했을 때의 응급처치 방법은 무엇인가요?",
#     "ANSWER": "스포츠 현장에서 화상 사고가 발생했을 때는 화상 부위를 흐르는 찬물에 적어도 10분 동안 담그고, 상처 부위를 깨끗하고 멸균 처리된 거즈로 덮어야 합니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "스포츠 활동 중 화재가 발생했을 때 어떻게 대처해야 하나요?",
#         "ANSWER": "화재가 발생했을 때는 즉시 안전한 장소로 대피하고, 화재 경보를 울리며, 소방서에 신고해야 합니다."
#     },
#     {
#         "QUESTION": "수중 스포츠 참여 중 익사 사고가 발생했을 때 어떻게 대처해야 하나요?",
#         "ANSWER": "익사 사고가 발생했을 때는 즉시 물속에서 사람을 구출하고, 인공호흡과 심폐소생술을 실시해야 합니다."
#     },
#     {
#         "QUESTION": "스포츠 현장에서 테러가 발생했을 때 어떻게 대처해야 하나요?",
#         "ANSWER": "테러가 발생했을 때는 즉시 안전한 장소로 대피하고, 경찰에 신고하며, 주변 사람들에게 경고하여 추가 피해를 방지해야 합니다."
#     }
# ]
# ``````json
# [
#     {
#         "QUESTION": "화재가 발생했을 때 가장 먼저 해야 할 일은 무엇인가요?",
#         "ANSWER": "화재가 발생했을 때 가장 먼저 해야 할 일은 '불이야'하고 큰소리로 외쳐 다른 사람들에게 알리는 것입니다."
#     },
#     {
#         "QUESTION": "화재 발생 시 119에 신고할 때 어떤 정보를 제공해야 하나요?",
#         "ANSWER": "화재 발생 시 119에 신고할 때는 불이 난 사실을 말하며 화재의 내용을 간단하고 명료하게 설명하고, 주소를 알려줘야 합니다."
#     },
#     {
#         "QUESTION": "화재 신고 후 전화를 끊을 때 주의해야 할 점은 무엇인가요?",
#         "ANSWER": "화재 신고 후에는 119에서 전화를 끊으라고 하기 전에 먼저 전화를 끊지 않아야 합니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "연기가 많은 상황에서 대피할 때는 어떻게 해야 하나요?",
#     "ANSWER": "연기가 많은 상황에서는 연기층 아래에 맑은 공기층이 있기 때문에 최대한 낮은 자세로 팔과 무릎으로 기어서 이동하되, 바닥에 배를 대고 가지 않습니다. 또한 코와 입을 젖은 수건 등으로 막아 연기가 폐에 들어가지 않도록 합니다."
# },
# {
#     "QUESTION": "불길 속을 통과해야 할 때는 어떻게 해야 하나요?",
#     "ANSWER": "불길 속을 통과할 때는 온몸에 물을 뿌리거나 물에 적신 담요 또는 수건 등으로 몸과 얼굴을 잘 감싼 후 대피합니다. 옷에 불이 붙었을 때에는 두 손으로 눈과 입을 가리고 바닥에서 뒹굽니다."
# },
# {
#     "QUESTION": "건물 밖으로 대피할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "건물 밖으로 대피할 때는 승강기를 절대 이용하지 않고 계단을 이용해야 합니다. 아래층으로 대피하지 못하는 경우에는 옥상으로 대피합니다."
# }
# ``````json
# {
#     "QUESTION": "소규모 화재 발생 시 어떤 소화기를 사용해야 하나요?",
#     "ANSWER": "소규모 화재 발생 시 분말소화기와 투척용 소화기를 사용할 수 있습니다."
# },
# {
#     "QUESTION": "분말 소화기를 사용할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "분말 소화기를 사용할 때는 바람을 뒤로하고 소화기 호스를 불이 난 곳으로 향하게 잡고, 소화기 안전핀을 뽑은 후 손잡이를 꽉 잡고 불을 향해 빗자루로 쓸 듯이 소화액을 뿌려야 합니다."
# },
# {
#     "QUESTION": "투척용 소화기는 어떻게 사용하나요?",
#     "ANSWER": "투척용 소화기는 커버를 벗기고 약재를 꺼낸 후 불을 향해 던지면 됩니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "지진 발생 시 실내에서 어떻게 대처해야 하나요?",
#         "ANSWER": "지진 발생 시 실내에서는 운동을 즉시 중단한 후 책상 또는 탁자 밑으로 몸을 피하고 넘어지기 쉬운 물건 주변은 피해야 합니다."
#     },
#     {
#         "QUESTION": "지진 발생 시 실외에서 어떻게 대처해야 하나요?",
#         "ANSWER": "지진 발생 시 실외에서는 운동을 즉시 중단하고 위험 요소(담장, 간판, 산사태 등)를 피해 넓은 공터로 대피해야 합니다."
#     },
#     {
#         "QUESTION": "천재지변 사고의 종류에는 어떤 것들이 있나요?",
#         "ANSWER": "천재지변 사고의 종류에는 지진, 집중호우·태풍, 폭염·폭설, 천둥·번개·낙뢰 등이 있습니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "집중호우나 태풍 발생 시 수상스포츠 중에는 어떻게 대처해야 하나요?",
#     "ANSWER": "집중호우나 태풍 발생 시 수상스포츠 중에는 조명시설 및 고압전선 근처에 가지 않고, 실외 운동을 즉시 중단하고 가까운 건물 내부로 이동해야 합니다."
# },
# {
#     "QUESTION": "집중호우가 발생했을 때 물건은 어떻게 해야 하나요?",
#     "ANSWER": "집중호우가 발생했을 때 물에 떠내려가거나 바람에 날아갈 위험이 있는 물건은 안전한 장소로 옮겨야 합니다."
# },
# {
#     "QUESTION": "태풍의 정의는 무엇인가요?",
#     "ANSWER": "태풍은 열대해상에서 발생하는 열대성 저기압 중 중심 부근의 최대 풍속이 17m/s 이상으로 주변 지역에 폭풍우를 동반하는 기상현상입니다."
# }
# ``````json
# {
#     "QUESTION": "폭염 발생 시 실외 운동을 하고 있을 때 어떻게 대처해야 하나요?",
#     "ANSWER": "폭염 발생 시 실외 운동을 하고 있을 경우 즉시 운동을 중단하고 통풍이 잘 되는 그늘이나 선풍기 및 에어컨이 작동되는 실내로 이동해야 합니다."
# },
# {
#     "QUESTION": "폭설 발생 시 신체 끝부분을 보호하기 위해 어떤 조치를 취해야 하나요?",
#     "ANSWER": "폭설 발생 시 손가락, 발가락, 코끝 등 신체 끝부분은 동상이 걸리기 쉬우므로 장갑, 두꺼운 양말, 모자 등으로 체온을 유지해야 합니다."
# },
# {
#     "QUESTION": "폭염과 폭설의 정의는 무엇인가요?",
#     "ANSWER": "폭염은 갑작스럽게 찾아오는 심한 더위를 말하며 일반적으로 30℃ 이상의 더위가 계속되는 현상입니다. 폭설은 짧은 시간에 많은 양의 눈이 오는 현상으로, 평소에 눈이 올 때보다 더 많은 눈이 내려 피해가 예상되는 경우를 의미합니다."
# }
# ``````json
# {
#     "QUESTION": "낙뢰에 맞았을 경우 의식이 없는 환자에게는 어떻게 응급처치를 해야 하나요?",
#     "ANSWER": "낙뢰에 맞아 의식이 없는 환자에게는 즉시 기도를 열어 호흡을 하는지 확인하고, 호흡을 하지 않으면 인공호흡과 함께 심장마사지를 합니다."
# },
# {
#     "QUESTION": "천둥과 번개가 예상될 때 스포츠 활동 중인 사람들은 어떻게 대처해야 하나요?",
#     "ANSWER": "천둥과 번개가 예상되면 스포츠 활동을 중단하고 참여자들이 최대한 몸을 낮춰 실내로 대피하거나, 움푹 파인 곳으로 대피할 수 있도록 유도합니다."
# },
# {
#     "QUESTION": "수상활동 중 번개를 처음 보거나 천둥소리를 들었을 때는 어떻게 해야 하나요?",
#     "ANSWER": "수상활동 중 번개를 처음 보거나 천둥소리를 들었을 때는 즉시 물에서 나오도록 하며 안전한 큰 건물로 대피할 수 있도록 합니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "붕괴사고 발생 시 건물 안에서 어떻게 대처해야 하나요?",
#         "ANSWER": "붕괴사고 발생 시 당황하지 않고 건물을 빠져나갈 수 있는 대피 경로를 찾아야 하며, 유리파편이나 떨어지는 물건에 다치지 않도록 옷 등으로 머리와 얼굴을 보호해야 합니다."
#     },
#     {
#         "QUESTION": "붕괴사고 시 부상자를 어떻게 처리해야 하나요?",
#         "ANSWER": "붕괴사고 시 부상자는 가능한 응급처치를 한 후 함께 탈출해야 합니다."
#     },
#     {
#         "QUESTION": "붕괴사고 후 건물 밖으로 나왔을 때 주의해야 할 점은 무엇인가요?",
#         "ANSWER": "붕괴사고 후 건물 밖으로 나오면 추가붕괴, 가스폭발, 화재 등에 대비하여 위험이 없는 안전한 지역으로 대피해야 합니다."
#     }
# ]
# ``````json
# {
#     "QUESTION": "붕괴된 건물에 갇혔을 때 체력을 소모하지 않기 위해 어떻게 해야 하나요?",
#     "ANSWER": "불필요한 활동이나 고함으로 체력을 소모하지 말고 가급적 편안한 자세를 유지합니다."
# },
# {
#     "QUESTION": "붕괴된 건물에서 먼지 흡입을 최소화하기 위해 어떻게 해야 하나요?",
#     "ANSWER": "입과 코를 옷 등으로 가려 먼지 흡입을 최소화 합니다."
# },
# {
#     "QUESTION": "붕괴의 예비 징후 중 하나는 무엇인가요?",
#     "ANSWER": "붕괴의 예비 징후 중 하나는 문이나 창문이 뒤틀리고 열고 닫기가 곤란할 때입니다."
# }
# ``````json
# {
#     "QUESTION": "테러 사고 중 폭발물이 사용된 경우 어떻게 대처해야 하나요?",
#     "ANSWER": "폭발물이 사용된 테러 사고에서는 즉시 안전한 장소로 대피하고, 부상자가 있을 경우 응급처치를 제공하며, 가능한 한 빨리 전문 의료진의 도움을 받는 것이 중요합니다."
# },
# {
#     "QUESTION": "총격 테러가 발생했을 때는 어떻게 해야 하나요?",
#     "ANSWER": "총격 테러가 발생했을 때는 즉시 몸을 숨길 수 있는 안전한 장소로 이동하고, 경찰이나 보안 요원에게 상황을 알리며, 부상자가 있을 경우 응급처치를 시도해야 합니다."
# },
# {
#     "QUESTION": "화학물 테러가 발생했을 때는 어떤 조치를 취해야 하나요?",
#     "ANSWER": "화학물 테러가 발생했을 때는 즉시 오염된 지역을 벗어나고, 노출된 피부나 옷을 깨끗한 물로 씻어내며, 가능한 한 빨리 의료진의 도움을 받아야 합니다."
# }
# ``````json
# {
#     "QUESTION": "총격테러 발생 시 어떻게 대처해야 하나요?",
#     "ANSWER": "총기 난사 시 일단 엎드린 후 상황을 살피는 것이 최선입니다. 항상 낮은 자세를 유지하고, 상황이 허락하는 대로 즉시 '111' 또는 '112'에 신고합니다."
# },
# {
#     "QUESTION": "폭발물테러 발생 시 대피할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "폭발물 발견 시 즉시 반대방향으로 대피하며, 승강기는 사용하지 않고 계단으로 대피합니다. 휴대전화, 라디오, 무전기 등은 기폭장치를 작동시킬 수 있으므로 사용하지 않아야 합니다."
# },
# {
#     "QUESTION": "방사능테러 발생 시 방사능에 노출되었다고 판단되면 어떻게 해야 하나요?",
#     "ANSWER": "방사능에 노출되었다고 판단되면 오염된 옷을 벗고 온몸을 깨끗하게 씻어야 합니다."
# }
# ``````json
# {
#     "QUESTION": "납치·감금 상황에서 탈출을 시도해야 할 때는 언제인가요?",
#     "ANSWER": "납치·감금 시 탈출 가능성이 높지 않으면 탈출을 시도하지 않습니다."
# },
# {
#     "QUESTION": "화학물질에 노출되었을 때 가장 먼저 해야 할 일은 무엇인가요?",
#     "ANSWER": "화학물질에 노출된 경우, 즉시 '111' 또는 '112'에 신고합니다."
# },
# {
#     "QUESTION": "화학테러 발생 시 차량으로 이동할 때 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "차량으로 이동할 때에는 창문을 닫고 에어컨과 히터를 켜지 않습니다."
# }
# ``````json
# {
#     "QUESTION": "테러 의심 우편물을 발견했을 때 가장 먼저 해야 할 일은 무엇인가요?",
#     "ANSWER": "테러 의심 우편물을 발견했을 때는 즉시 '111' 또는 '112'에 신고해야 합니다."
# },
# {
#     "QUESTION": "화생방 물질이 포함된 우편물을 개봉했을 경우 어떻게 대처해야 하나요?",
#     "ANSWER": "화생방 물질이 포함된 우편물을 개봉했을 경우, 우편물에 접촉하지 말고 수건으로 코와 입을 막고 우편물 개봉장소를 즉시 떠나야 합니다."
# },
# {
#     "QUESTION": "사제폭탄이 포함된 우편물을 개봉했을 때의 대처 방법은 무엇인가요?",
#     "ANSWER": "사제폭탄이 포함된 우편물을 개봉했을 때는 즉시 그 장소를 떠난 후 '111' 또는 '112'에 신고해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "바다에 빠졌을 때 체력 소모를 줄이기 위한 방법은 무엇인가요?",
#     "ANSWER": "바다에 빠졌을 때 체력 소모를 줄이기 위해서는 긴장을 풀고 몸에 힘을 최대한 뺀 상태로 수영하는 것이 중요합니다."
# },
# {
#     "QUESTION": "수중에서 경련이 발생했을 때 어떻게 대처해야 하나요?",
#     "ANSWER": "수중에서 경련이 발생했을 때 가장 중요한 것은 근육을 펴는 것입니다. 당황해서 몸을 함부로 움직이면 익사 위험이 있으므로 주의해야 합니다."
# },
# {
#     "QUESTION": "큰 파도에 휩싸였을 때 어떻게 해야 하나요?",
#     "ANSWER": "큰 파도에 휩싸였을 때는 버둥거리지 않고 파도에 몸을 맡긴 후 숨을 크게 들이마시고 중지해 있으면 자연스럽게 몸이 떠오릅니다."
# }
# ``````json
# {
#     "QUESTION": "물에서 경련이 발생했을 때 첫 번째로 해야 할 일은 무엇인가요?",
#     "ANSWER": "몸을 둥글게 모으고 물위에 뜨도록 합니다."
# },
# {
#     "QUESTION": "경련이 난 쪽의 근육을 풀기 위해 어떤 방법을 사용해야 하나요?",
#     "ANSWER": "숨을 크게 들이마시고 물속에 얼굴을 넣은 채 근육 경련이 풀릴 때까지 쥐가 난 쪽의 엄지발가락을 힘껏 앞으로 꺾어 잡아당깁니다."
# },
# {
#     "QUESTION": "경련이 가라앉은 후에도 주의해야 할 점은 무엇인가요?",
#     "ANSWER": "근육 경련은 가라앉아도 다시 경련이 일어날 가능성이 있으므로 물 밖에서 근육 경련 부위를 충분히 마사지 해줍니다."
# }
# ``````json
# {
#     "QUESTION": "셔츠를 이용하여 물에 뜨게 하는 방법은 무엇인가요?",
#     "ANSWER": "셔츠의 목 쪽에 공기가 새지 않게 조이고, 숨을 크게 들이마신 후 둘째와 셋째 단추 사이로 공기를 불어 넣으면 셔츠의 등 쪽에 물거품 모양이 형성되어 뜰 수 있습니다."
# },
# {
#     "QUESTION": "바지를 이용하여 물에 뜨게 하는 방법은 무엇인가요?",
#     "ANSWER": "바지의 발목 쪽을 공기가 새지 않도록 단단하게 묶고, 허리 좌우를 양손으로 잡고 머리 뒤로 넘긴 후 양손을 앞쪽 수면을 향해 강하게 내리치며 바지의 허리 쪽을 통해 공기가 들어가도록 하면 바지의 다리 쪽에 공기가 들어가 뜰 수 있습니다."
# },
# {
#     "QUESTION": "조류에 휘말렸을 때 어떻게 수영해야 하나요?",
#     "ANSWER": "조류에 휘말렸을 때는 당황하거나 피하려고 몸부림치지 말고 조류를 따라서 비스듬히 해변을 향해 헤엄쳐야 합니다."
# }
# ``````json
# {
#     "QUESTION": "수중에서 익수자를 발견했을 때 가장 먼저 해야 할 일은 무엇인가요?",
#     "ANSWER": "익수자를 발견한 경우 주변에 큰 소리로 '사람이 빠졌습니다. 119에 신고해주세요.'라고 외쳐서 모두가 알 수 있도록 합니다."
# },
# {
#     "QUESTION": "익수자를 구조할 때 직접 물에 뛰어드는 것은 언제 해야 하나요?",
#     "ANSWER": "직접 물에 뛰어드는 것은 최후의 수단으로, 무턱대고 입수하기 보다는 주변 상황을 빠르게 살펴보고 익수자에게 물에 떠 있을 수 있도록 도와주는 장비를 제공하는 것이 안전합니다."
# },
# {
#     "QUESTION": "의식이 있는 익수자를 구조할 때 접근 방법은 어떻게 해야 하나요?",
#     "ANSWER": "의식이 있는 익수자를 구조할 때에는 반드시 뒤쪽으로부터 접근해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "의식이 없는 사고자를 구조하였을 때 가장 먼저 해야 할 응급처치는 무엇인가요?",
#     "ANSWER": "의식이 없는 사고자를 구조하였을 때 가장 먼저 해야 할 응급처치는 인공호흡입니다."
# },
# {
#     "QUESTION": "물에 빠진 사람을 발견했을 때 물속으로 뛰어들어 구조해야 하나요?",
#     "ANSWER": "물에 빠진 사람을 발견했을 때 절대로 물속으로 뛰어들어 구조하지 않습니다."
# },
# {
#     "QUESTION": "익사사고 발견 시 누구에게 신고해야 하나요?",
#     "ANSWER": "익사사고 발견 시 운영요원, 지도자 또는 인근 소방관서(119), 해양수상구조대(122)에 신속하게 신고합니다."
# }
# ``````json
# [
#     {
#         "QUESTION": "스포츠안전교육에 대한 상담을 받으려면 어떻게 해야 하나요?",
#         "ANSWER": "스포츠안전교육에 대한 상담을 받으시려면 02-425-5952로 전화하시면 됩니다."
#     },
#     {
#         "QUESTION": "응급처치 매뉴얼의 무단 전재 및 배포는 가능한가요?",
#         "ANSWER": "응급처치 매뉴얼의 무단 전재 및 배포는 금지되어 있습니다."
#     },
#     {
#         "QUESTION": "스포츠안전재단의 위치는 어디인가요?",
#         "ANSWER": "스포츠안전재단은 서울특별시 송파구 백제고분로 508 제일빌딩(방이동 180-4) 4층에 위치해 있습니다."
#     }
# ]
# ``````json
# [
#     {
#         "QUESTION": "스포츠 안전 교육에 대한 상담을 받으려면 어떻게 해야 하나요?",
#         "ANSWER": "스포츠 안전 교육에 대한 상담을 받으려면 02-425-5952로 전화하시면 됩니다."
#     },
#     {
#         "QUESTION": "스포츠안전재단의 안전사업팀은 어디에 위치해 있나요?",
#         "ANSWER": "스포츠안전재단의 안전사업팀은 서울시 송파구 백제고분로 508 제일빌딩 4층에 위치해 있습니다."
#     },
#     {
#         "QUESTION": "스포츠안전재단의 웹사이트 주소는 무엇인가요?",
#         "ANSWER": "스포츠안전재단의 웹사이트 주소는 www.sportsafety.or.kr입니다."
#     }
# ]
# ```QA dataset saved to qa_dataset.json

# %%
# 데이터 형식 변형
fine_tune_data = []

for pair in qa_pair:
  if type(pair) == list:
    for qa in pair:
      message = {'messages' : []}
      system_message = {'role' : 'system'}
      user_message = {'role' : 'user'}
      ai_message = {'role' : 'assistant'}

      system_message['content'] = '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'
      user_message['content'] = qa['QUESTION']
      ai_message['content'] = qa['ANSWER']

      message['messages'].append(system_message)
      message['messages'].append(user_message)
      message['messages'].append(ai_message)

      fine_tune_data.append(message)

  elif type(pair) == dict:
    message = {'messages' : []}
    system_message = {'role' : 'system'}
    user_message = {'role' : 'user'}
    ai_message = {'role' : 'assistant'}

    system_message['content'] = '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'
    user_message['content'] = pair['QUESTION']
    ai_message['content'] = pair['ANSWER']

    message['messages'].append(system_message)
    message['messages'].append(user_message)
    message['messages'].append(ai_message)

    fine_tune_data.append(message)



# jsonl 파일 경로
file_path = 'qa_dataset.jsonl'

# jsonl 파일로 저장
with open(file_path, 'w', encoding='utf-8') as f:
    for item in fine_tune_data:
        # 각 딕셔너리를 JSON 문자열로 변환 후 한 줄씩 파일에 기록
        f.write(json.dumps(item, ensure_ascii=False) + '\n')

# %%
fine_tune_data
# Out:
# [{'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '응급처치 매뉴얼이란 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '응급처치 매뉴얼은 응급 상황에서 적절한 조치를 취할 수 있도록 안내하는 지침서입니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '심정지 상황에서 심폐소생술은 어떻게 수행하나요?'},
#    {'role': 'assistant',
#     'content': '심정지 상황에서는 즉시 심폐소생술을 시작해야 하며, 가슴 압박과 인공호흡을 번갈아 가며 수행합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '열사병이 발생했을 때는 어떻게 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '열사병이 발생했을 때는 즉시 시원한 장소로 이동시키고, 옷을 느슨하게 하며, 체온을 낮추기 위해 물을 뿌리거나 젖은 수건으로 몸을 닦아줍니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '응급처치의 기본 원칙은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '응급처치의 기본 원칙은 환자의 상태를 신속하게 평가하고, 필요한 경우 즉시 응급처치를 제공하여 생명을 구하고 상태를 안정시키는 것입니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '응급처치 시 가장 먼저 해야 할 일은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '응급처치 시 가장 먼저 해야 할 일은 주변의 안전을 확인하고, 환자의 의식과 호흡을 평가하는 것입니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '응급처치 교육의 중요성은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '응급처치 교육은 비상 상황에서 적절한 대처를 통해 생명을 구하고 부상 정도를 최소화할 수 있도록 도와주는 중요한 지식과 기술을 제공합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user',
#     'content': '스포츠 활동 중 응급상황이 발생했을 때 왜 신속하고 적절한 응급처치가 중요한가요?'},
#    {'role': 'assistant',
#     'content': '응급처치를 얼마나 신속하고 적절하게 실시하였는가에 따라 부상자의 삶과 죽음, 일시적 장애와 영구적인 손상이 결정되기 때문에 매우 중요합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '응급상황에서의 행동절차 3C는 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '응급상황에서의 행동절차 3C는 현장조사(Check), 119 신고(Call), 처치 및 도움(Care)입니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '응급상황 발생 시 119에 신고할 때 주의해야 할 점은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '즉시 전화하고 필수 정보를 알리며, 질문에 대답하고 전화를 먼저 끊지 않으며 신고 후 지체 없이 처치해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '스포츠 활동 중 응급상황 발생 시 가장 먼저 해야 할 일은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '스포츠 활동 중 응급상황이 발생하면 가장 먼저 119에 신고하여 구급대원이 현장에 빨리 도착할 수 있도록 하는 것이 중요합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '응급상황에서 환자의 상태를 확인할 때 어떤 점을 주의 깊게 살펴봐야 하나요?'},
#    {'role': 'assistant',
#     'content': '응급상황에서 환자의 상태를 확인할 때는 의식이 있는지, 숨을 쉬는 것이 곤란한지, 가슴이나 목에 통증이 있는지, 이유 없이 땀을 흘리지는 않는지, 피부색이 창백하거나 푸르게 변하지는 않는지를 주의 깊게 살펴봐야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user',
#     'content': '응급처치를 할 때 환자의 분비물과 접촉을 피하기 위해 어떤 장비를 사용해야 하나요?'},
#    {'role': 'assistant',
#     'content': '응급처치를 할 때 환자의 분비물과 직접적인 접촉을 피하기 위해 소독장갑이나 보호 장비를 사용해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '전봇대의 고유번호는 어떤 상황에서 유용하게 사용될 수 있나요?'},
#    {'role': 'assistant',
#     'content': '전봇대의 고유번호는 낯선 곳에서 자신의 위치를 파악할 때 유용하게 사용될 수 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '응급처치를 시작하기 전에 환자에게 어떤 절차를 따라야 하나요?'},
#    {'role': 'assistant',
#     'content': '응급처치를 시작하기 전에 환자에게 사전 동의를 구해야 하며, 자신의 이름, 신분 및 응급처치 교육경력을 밝히고 앞으로 행할 응급처치에 대한 설명을 해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '기도를 방해하거나 폐쇄를 일으킬 수 있는 손상에는 어떤 것들이 있나요?'},
#    {'role': 'assistant',
#     'content': '기도를 방해하거나 폐쇄를 일으킬 수 있는 손상에는 흡인성 손상, 흉곽 손상, 긴장성 기흉, 질식을 초래하거나 질식 상태에 있는 상악이나 안면의 손상이 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '즉각적인 지혈이 필요한 경우는 어떤 상황인가요?'},
#    {'role': 'assistant',
#     'content': '즉각적인 지혈이 필요한 경우는 즉각적 지혈을 요하는 모든 출혈 상황입니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '응급 처치 시 우선 순위는 어떻게 되나요?'},
#    {'role': 'assistant',
#     'content': '응급 처치 시 우선 순위는 즉각적인 처치를 요하는 환자와 긴급 수술을 요하는 환자가 1순위이며, 수술이 필요하지만 지연이 가능한 환자가 2순위입니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '선한 사마리아인법이란 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '선한 사마리아인법은 고통 받는 사람을 기꺼이 도와주기 위하여, 즉 도덕적 의무를 이행하다가 예기치 않은 피해가 발생하더라도 고의나 중대한 과실이 없을 경우에는 민, 형사상 책임을 면제하는 것을 의미합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '선한 사마리아인법이 적용되기 위한 조건은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '선한 사마리아인법이 적용되기 위해서는 생명이 위급한 상황에서 행동을 하고, 올바른 신념에 따라 행동하며, 보상을 바라지 않고 행동하고, 악의에 찬 행위 또는 지나친 과실을 범하지 않아야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user',
#     'content': '응급의료종사자가 아닌 사람이 응급처치를 제공할 때 책임이 면제되는 경우는 언제인가요?'},
#    {'role': 'assistant',
#     'content': '응급의료종사자가 아닌 자가 응급처치를 제공하여 발생한 재산상 손해와 사상에 대하여 고의 또는 중대한 과실이 없는 경우 그 행위자는 민사 책임과 상해에 대한 형사 책임을 지지 아니하고 사망에 대한 형사 책임은 감면됩니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '심정지 상황에서 가장 먼저 해야 할 응급처치는 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '심정지 상황에서는 즉시 심폐소생술(CPR)을 시작하는 것이 가장 중요합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '심정지 환자를 발견했을 때 가장 먼저 해야 할 일은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '심정지 환자를 발견하면 즉시 의료인에게 도움을 청해야 하며 심폐소생술을 실시해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '심폐소생술을 시작하기 전에 환자에게 어떤 반응을 확인해야 하나요?'},
#    {'role': 'assistant',
#     'content': "환자의 어깨를 가볍게 두드리며 큰소리로 '괜찮으세요?'라고 물어보며 반응을 확인하고, 특정인을 지목하여 119신고를 요청해야 합니다."}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '자동심장충격기(AED)를 사용할 때 첫 번째 단계는 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '자동심장충격기(AED)를 사용할 때 첫 번째 단계는 전원을 켜는 것입니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '자동심장충격기(AED)의 위치를 어떻게 찾을 수 있나요?'},
#    {'role': 'assistant',
#     'content': "휴대폰 어플리케이션인 '응급의료정보제공'을 다운받아 '제세동기 찾기' 메뉴를 통해 현 위치를 중심으로 자동심장충격기가 설치된 위치를 알 수 있습니다."}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '근골격계 손상 시 응급처치는 어떻게 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '근골격계 손상 시에는 부상 부위를 고정하고, 가능한 한 움직이지 않도록 하며, 즉시 의료기관을 방문하여 전문적인 치료를 받는 것이 중요합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '염좌가 발생했을 때 나타나는 증상은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '염좌가 발생한 부위는 붓고 빨개지며 통증이 생기고, 누르면 아프며 멍이 들기도 하고 관절이 경직되어 운동성이 감소합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': "R.I.C.E. 응급처치에서 '안정'은 무엇을 의미하나요?"},
#    {'role': 'assistant',
#     'content': "R.I.C.E. 응급처치에서 '안정'은 상처부위를 되도록 움직이지 않도록 하고 경우에 따라 고정시키는 것을 의미합니다."}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '골절된 부위를 옮겨야 할 때 어떤 조치를 취해야 하나요?'},
#    {'role': 'assistant',
#     'content': '골절 부위가 2차 손상을 일으키지 않도록 반드시 부목을 댄 후 운반해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '부목고정의 목적은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '부목고정의 목적은 상처 부위의 부러진 뼈에 의해 생길 수 있는 추가적인 손상을 방지하거나, 복잡 골절로 악화되는 것을 방지하고, 뼈에 의해 혈관이 압박되어 골절 원위부의 혈액순환이 차단되는 것을 방지하는 것입니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '골절이 확실하지 않더라도 손상이 의심될 때는 어떻게 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '골절이 확실하지 않더라도 손상이 의심될 때는 부목을 이용하여 고정해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '부목을 댄 후에 주기적으로 확인해야 하는 것은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '부목을 댄 후에도 골절 원위부에서 맥박, 감각, 운동기능을 주기적으로 확인해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '골절된 부위에 부목을 고정할 때 어떤 길이의 부목을 사용해야 하나요?'},
#    {'role': 'assistant',
#     'content': '부목은 골절된 뼈의 양쪽 관절 너머까지 걸칠 만큼 긴 것을 사용해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '부목을 사용할 때 피부 손상을 방지하기 위해 어떤 조치를 취해야 하나요?'},
#    {'role': 'assistant',
#     'content': '부목 안쪽에 헝겊을 고여서 피부가 상하지 않도록 해야 하며, 가능한 가볍고 단단한 것을 사용해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '적당한 부목이 없을 경우 어떤 대체물을 사용할 수 있나요?'},
#    {'role': 'assistant',
#     'content': '적당한 부목이 없을 경우 환자의 전신 또는 일부분을 신문지 뭉치, 잡지, 담요, 베개 등을 대응 부목으로 사용할 수 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '근육경련이 발생했을 때 어떻게 응급처치를 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '환자를 눕혀 편안한 자세를 유지시키며 안정을 취하도록 하고, 경련 부위가 종아리 근육이거나 뒤쪽 허벅지인 경우 다리를 쭉 핀 상태에서 발목을 몸 쪽으로 서서히 당겨줍니다. 경련 부위가 허벅지 근육이면 다리부분을 뒤로 굽히는 등 근육경련이 발생한 근육을 반대편으로 당겨줍니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '출혈이 발생했을 때 가장 먼저 해야 할 응급처치는 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '출혈이 발생했을 때 가장 먼저 해야 할 응급처치는 출혈 부위를 압박하여 지혈하는 것입니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '출혈이 심한 경우 나타날 수 있는 증상은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '출혈이 심한 경우 호흡과 맥박이 빨라지고 호흡 곤란이 발생할 수 있으며, 피부가 창백해지고 체온이 떨어질 수 있습니다. 또한 갈증을 느끼면서 동공이 확대되며 구토가 발생할 수도 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '직접 압박 지혈은 어떻게 수행하나요?'},
#    {'role': 'assistant',
#     'content': '직접 압박 지혈은 출혈 부위를 소독거즈로 덮은 후 손으로 압박하여 출혈을 멈추는 방법입니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '직접 압박으로 지혈되지 않는 경우 어떤 방법을 사용하나요?'},
#    {'role': 'assistant',
#     'content': '직접 압박으로 지혈되지 않는 경우 해당 동맥과 가까운 지혈점을 압박함으로써 심한 출혈을 억제하는 방법을 사용합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '지혈대는 언제 사용해야 하나요?'},
#    {'role': 'assistant',
#     'content': '지혈대는 직접 압박과 혈관 압박으로도 출혈을 멈출 수 없을 때에 사용되는 방법입니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '충격에 의해 신체 손상을 입었을 때 가장 먼저 해야 할 응급처치는 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '충격에 의해 신체 손상을 입었을 때는 즉시 손상 부위를 확인하고, 출혈이 있는 경우에는 깨끗한 천으로 압박하여 지혈을 시도합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '뇌진탕이 발생했을 때 의식이 없는 경우 어떻게 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '환자의 의식 여부를 확인한 후 의식이 없다면 즉시 심폐소생술을 실시해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '치아가 흔들릴 경우 어떻게 응급처치를 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '치아가 흔들릴 경우에는 잇몸을 깨끗한 천 등으로 눌러 지혈하고, 통증과 흔들림이 지속된다면 최대한 빠른 시간내에 병원을 내원하여 진료를 받아야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '두개골 골절 시 어떤 증상이 나타날 수 있나요?'},
#    {'role': 'assistant',
#     'content': '두개골 골절 시 극심한 통증과 머리 모양의 변형 또는 상처의 흔적이 생기며, 두피가 안쪽으로 들어가거나 말랑말랑한 혹이 생기고 머리, 얼굴 모양이 변형될 수 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '온도변화로 인한 신체손상에는 어떤 종류가 있나요?'},
#    {'role': 'assistant', 'content': '온도변화로 인한 신체손상에는 저체온증과 열사병이 포함됩니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '스포츠 활동 중 열사병이 발생했을 때 어떻게 대처해야 하나요?'},
#    {'role': 'assistant',
#     'content': '열사병이 발생했을 때는 즉시 시원한 장소로 이동하여 몸을 식히고, 물을 충분히 마시며, 필요시 의료진의 도움을 받아야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '저체온증이 의심될 때 어떤 조치를 취해야 하나요?'},
#    {'role': 'assistant',
#     'content': '저체온증이 의심될 때는 따뜻한 장소로 이동하여 젖은 옷을 제거하고, 담요로 몸을 감싸 체온을 유지하며, 따뜻한 음료를 제공하여 체온을 회복시켜야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '동상이 발생했을 때는 어떻게 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '동상이 발생했을 때는 동상 부위를 따뜻한 물에 담가 서서히 녹이고, 문지르지 않도록 주의하며, 심한 경우에는 즉시 의료진의 도움을 받아야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '화상을 입었을 때 피부의 열기를 줄이기 위해 어떻게 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '피부의 열기를 줄이기 위해 흐르는 물에 15분 이상 환부를 차게 합니다. 차가운 수돗물이나 얼음을 넣은 비닐봉투 등을 활용해도 좋습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '화상 부위에 옷이 달라붙었을 때는 어떻게 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '화상 부위에 옷이 달라붙었다면 옷을 벗기다 피부에 손상을 줄 수 있으니 가위를 이용해 옷을 찢어야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '화상 부위에 얼음을 대면 안 되는 이유는 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '화상 부위에 얼음을 대면 혈관 수축으로 염증성 물집이 생성되어 증상을 더욱 악화시킬 수 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '화상 치료 후 상처 부위를 자외선으로부터 보호하는 방법은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '상처가 자외선에 노출되면 피부 변색을 일으킬 수 있으므로 외출할 때에는 자외선차단제를 반드시 발라주고, 상처부위를 가리는 부드러운 면 소재의 옷을 입는 것이 좋습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '열사병이 발생했을 때 나타날 수 있는 증상은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '열사병이 발생했을 때 체온이 40도까지 상승할 수 있으며, 땀을 흘리지 않거나 의식 및 행동의 변화(가벼운 혼동, 지남력상실, 무의식)가 나타날 수 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '일사병이 발생했을 때 응급처치 방법은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '일사병이 발생했을 때는 환자를 그늘진 시원한 장소로 옮기고 옷을 벗긴 후에 편안한 자세를 취하게 하며, 다리를 편 상태로 20~30cm 정도 높여줍니다. 입으로 소금이 들어간 찬 물 또는 이온음료를 마시게 하고, 찬물을 묻힌 스펀지로 몸을 적신 후에 부채질을 해줍니다. 30분 이내에 증상이 회복되지 않으면 병원으로 이송합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '동상이란 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '동상은 신체 조직의 일부가 언 상태를 의미하며, 주로 스포츠 활동 시 저온에 노출된 신체 부위에 발생합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '저체온증이 발생했을 때 가장 먼저 해야 할 일은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '저체온증이 발생했을 때 가장 먼저 해야 할 일은 즉시 119에 신고하는 것입니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '응급처치가 필요한 질환에는 어떤 것들이 있나요?'},
#    {'role': 'assistant', 'content': '응급처치가 필요한 질환에는 화상, 벌에 쏘임, 골절 등이 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '응급처치 시 주의해야 할 점은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '응급처치 시에는 상처 부위를 깨끗하게 유지하고, 가능한 경우 멸균 처리된 거즈를 사용하여 감염을 방지해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '응급처치의 목적은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '응급처치의 목적은 부상이나 질환으로 인한 추가적인 손상을 방지하고, 환자의 상태를 안정화시키는 것입니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '뇌졸중이 발생했을 때 어떤 증상이 나타날 수 있나요?'},
#    {'role': 'assistant',
#     'content': '뇌졸중이 발생하면 얼굴이 한쪽으로 일그러지고, 한쪽 팔의 감각이 없어지며, 말이 새고 말하는 데 어려움이 생길 수 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '뇌졸중 환자를 발견했을 때 가장 먼저 해야 할 일은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '뇌졸중 환자를 발견하면 즉시 119에 신고한 뒤, 사고가 난 시간을 확인하고 환자의 상태를 관찰해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '천식 환자가 스포츠 활동을 할 때 주의해야 할 점은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '천식 환자는 기관지의 문제로 호흡이 어려워질 수 있으므로 갑작스럽고 격렬한 활동을 피하는 것이 좋습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user',
#     'content': '당뇨병 환자가 저혈당 쇼크를 예방하기 위해 운동 시 주의해야 할 점은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '당뇨병 환자는 과도한 운동을 피하고, 공복 상태에서 운동하지 않도록 주의해야 합니다. 운동 전 식사와 컨디션을 체크하고 틈틈이 간식을 섭취하는 것이 좋습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '저혈당 쇼크가 발생했을 때 의식이 있는 경우 어떻게 응급처치를 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '의식이 있는 경우 빨리 흡수되어 혈당을 올릴 수 있는 당질음식인 설탕물이나 꿀, 초콜릿, 각설탕 등을 섭취하도록 한 후, 운동을 멈추고 휴식하게 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '스포츠 현장에서 발생하는 재난 사고에 대한 일반적인 대응 절차는 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '스포츠 현장에서 발생하는 재난 사고에 대한 대응 절차는 사고의 종류에 따라 다르며, 각 사고에 맞는 적절한 응급처치와 안전 조치를 취하는 것이 중요합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '스포츠 활동 중 화재가 발생했을 때 어떻게 대처해야 하나요?'},
#    {'role': 'assistant',
#     'content': '화재가 발생했을 때는 즉시 안전한 장소로 대피하고, 화재 경보를 울리며, 소방서에 신고해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '수중 스포츠 참여 중 익사 사고가 발생했을 때 어떻게 대처해야 하나요?'},
#    {'role': 'assistant',
#     'content': '익사 사고가 발생했을 때는 즉시 물속에서 사람을 구출하고, 인공호흡과 심폐소생술을 실시해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '스포츠 현장에서 테러가 발생했을 때 어떻게 대처해야 하나요?'},
#    {'role': 'assistant',
#     'content': '테러가 발생했을 때는 즉시 안전한 장소로 대피하고, 경찰에 신고하며, 주변 사람들에게 경고하여 추가 피해를 방지해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '화재가 발생했을 때 가장 먼저 해야 할 일은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': "화재가 발생했을 때 가장 먼저 해야 할 일은 '불이야'하고 큰소리로 외쳐 다른 사람들에게 알리는 것입니다."}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '화재 발생 시 119에 신고할 때 어떤 정보를 제공해야 하나요?'},
#    {'role': 'assistant',
#     'content': '화재 발생 시 119에 신고할 때는 불이 난 사실을 말하며 화재의 내용을 간단하고 명료하게 설명하고, 주소를 알려줘야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '화재 신고 후 전화를 끊을 때 주의해야 할 점은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '화재 신고 후에는 119에서 전화를 끊으라고 하기 전에 먼저 전화를 끊지 않아야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '연기가 많은 상황에서 대피할 때는 어떻게 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '연기가 많은 상황에서는 연기층 아래에 맑은 공기층이 있기 때문에 최대한 낮은 자세로 팔과 무릎으로 기어서 이동하되, 바닥에 배를 대고 가지 않습니다. 또한 코와 입을 젖은 수건 등으로 막아 연기가 폐에 들어가지 않도록 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '소규모 화재 발생 시 어떤 소화기를 사용해야 하나요?'},
#    {'role': 'assistant',
#     'content': '소규모 화재 발생 시 분말소화기와 투척용 소화기를 사용할 수 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '지진 발생 시 실내에서 어떻게 대처해야 하나요?'},
#    {'role': 'assistant',
#     'content': '지진 발생 시 실내에서는 운동을 즉시 중단한 후 책상 또는 탁자 밑으로 몸을 피하고 넘어지기 쉬운 물건 주변은 피해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '지진 발생 시 실외에서 어떻게 대처해야 하나요?'},
#    {'role': 'assistant',
#     'content': '지진 발생 시 실외에서는 운동을 즉시 중단하고 위험 요소(담장, 간판, 산사태 등)를 피해 넓은 공터로 대피해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '천재지변 사고의 종류에는 어떤 것들이 있나요?'},
#    {'role': 'assistant',
#     'content': '천재지변 사고의 종류에는 지진, 집중호우·태풍, 폭염·폭설, 천둥·번개·낙뢰 등이 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '집중호우나 태풍 발생 시 수상스포츠 중에는 어떻게 대처해야 하나요?'},
#    {'role': 'assistant',
#     'content': '집중호우나 태풍 발생 시 수상스포츠 중에는 조명시설 및 고압전선 근처에 가지 않고, 실외 운동을 즉시 중단하고 가까운 건물 내부로 이동해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '폭염 발생 시 실외 운동을 하고 있을 때 어떻게 대처해야 하나요?'},
#    {'role': 'assistant',
#     'content': '폭염 발생 시 실외 운동을 하고 있을 경우 즉시 운동을 중단하고 통풍이 잘 되는 그늘이나 선풍기 및 에어컨이 작동되는 실내로 이동해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '낙뢰에 맞았을 경우 의식이 없는 환자에게는 어떻게 응급처치를 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '낙뢰에 맞아 의식이 없는 환자에게는 즉시 기도를 열어 호흡을 하는지 확인하고, 호흡을 하지 않으면 인공호흡과 함께 심장마사지를 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '붕괴사고 발생 시 건물 안에서 어떻게 대처해야 하나요?'},
#    {'role': 'assistant',
#     'content': '붕괴사고 발생 시 당황하지 않고 건물을 빠져나갈 수 있는 대피 경로를 찾아야 하며, 유리파편이나 떨어지는 물건에 다치지 않도록 옷 등으로 머리와 얼굴을 보호해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '붕괴사고 시 부상자를 어떻게 처리해야 하나요?'},
#    {'role': 'assistant',
#     'content': '붕괴사고 시 부상자는 가능한 응급처치를 한 후 함께 탈출해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '붕괴사고 후 건물 밖으로 나왔을 때 주의해야 할 점은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '붕괴사고 후 건물 밖으로 나오면 추가붕괴, 가스폭발, 화재 등에 대비하여 위험이 없는 안전한 지역으로 대피해야 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '붕괴된 건물에 갇혔을 때 체력을 소모하지 않기 위해 어떻게 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '불필요한 활동이나 고함으로 체력을 소모하지 말고 가급적 편안한 자세를 유지합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '테러 사고 중 폭발물이 사용된 경우 어떻게 대처해야 하나요?'},
#    {'role': 'assistant',
#     'content': '폭발물이 사용된 테러 사고에서는 즉시 안전한 장소로 대피하고, 부상자가 있을 경우 응급처치를 제공하며, 가능한 한 빨리 전문 의료진의 도움을 받는 것이 중요합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '총격테러 발생 시 어떻게 대처해야 하나요?'},
#    {'role': 'assistant',
#     'content': "총기 난사 시 일단 엎드린 후 상황을 살피는 것이 최선입니다. 항상 낮은 자세를 유지하고, 상황이 허락하는 대로 즉시 '111' 또는 '112'에 신고합니다."}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '납치·감금 상황에서 탈출을 시도해야 할 때는 언제인가요?'},
#    {'role': 'assistant', 'content': '납치·감금 시 탈출 가능성이 높지 않으면 탈출을 시도하지 않습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '테러 의심 우편물을 발견했을 때 가장 먼저 해야 할 일은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': "테러 의심 우편물을 발견했을 때는 즉시 '111' 또는 '112'에 신고해야 합니다."}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '바다에 빠졌을 때 체력 소모를 줄이기 위한 방법은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '바다에 빠졌을 때 체력 소모를 줄이기 위해서는 긴장을 풀고 몸에 힘을 최대한 뺀 상태로 수영하는 것이 중요합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '물에서 경련이 발생했을 때 첫 번째로 해야 할 일은 무엇인가요?'},
#    {'role': 'assistant', 'content': '몸을 둥글게 모으고 물위에 뜨도록 합니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '셔츠를 이용하여 물에 뜨게 하는 방법은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '셔츠의 목 쪽에 공기가 새지 않게 조이고, 숨을 크게 들이마신 후 둘째와 셋째 단추 사이로 공기를 불어 넣으면 셔츠의 등 쪽에 물거품 모양이 형성되어 뜰 수 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '수중에서 익수자를 발견했을 때 가장 먼저 해야 할 일은 무엇인가요?'},
#    {'role': 'assistant',
#     'content': "익수자를 발견한 경우 주변에 큰 소리로 '사람이 빠졌습니다. 119에 신고해주세요.'라고 외쳐서 모두가 알 수 있도록 합니다."}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '의식이 없는 사고자를 구조하였을 때 가장 먼저 해야 할 응급처치는 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '의식이 없는 사고자를 구조하였을 때 가장 먼저 해야 할 응급처치는 인공호흡입니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '스포츠안전교육에 대한 상담을 받으려면 어떻게 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '스포츠안전교육에 대한 상담을 받으시려면 02-425-5952로 전화하시면 됩니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '응급처치 매뉴얼의 무단 전재 및 배포는 가능한가요?'},
#    {'role': 'assistant', 'content': '응급처치 매뉴얼의 무단 전재 및 배포는 금지되어 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '스포츠안전재단의 위치는 어디인가요?'},
#    {'role': 'assistant',
#     'content': '스포츠안전재단은 서울특별시 송파구 백제고분로 508 제일빌딩(방이동 180-4) 4층에 위치해 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '스포츠 안전 교육에 대한 상담을 받으려면 어떻게 해야 하나요?'},
#    {'role': 'assistant',
#     'content': '스포츠 안전 교육에 대한 상담을 받으려면 02-425-5952로 전화하시면 됩니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '스포츠안전재단의 안전사업팀은 어디에 위치해 있나요?'},
#    {'role': 'assistant',
#     'content': '스포츠안전재단의 안전사업팀은 서울시 송파구 백제고분로 508 제일빌딩 4층에 위치해 있습니다.'}]},
#  {'messages': [{'role': 'system', 'content': '이 시스템은 응급처치 절차를 설명해주는 시스템입니다.'},
#    {'role': 'user', 'content': '스포츠안전재단의 웹사이트 주소는 무엇인가요?'},
#    {'role': 'assistant',
#     'content': '스포츠안전재단의 웹사이트 주소는 www.sportsafety.or.kr입니다.'}]}]

# %%
# 데이터 업로드
from openai import OpenAI

client = OpenAI(api_key=api_key)

response = client.files.create(
    file=open('qa_dataset.jsonl', 'rb'),
    purpose='fine-tune' # 데이터 파일의 목적 지정
)

file_id = response.id

# %%
file_id
# Out:
# 'file-9EbGvkJP6CjvYuBnjtEBE9'

# %%
# 모델 생성
client.fine_tuning.jobs.create(
    training_file=file_id, # 훈련할 데이터 세트 파일 ID
    model='gpt-4o-mini-2024-07-18', # 훈련시킬 모델 이름
    suffix= 'fine-tune-qadataset-model' # 훈련된 모델의 이름 지정
)
# Out:
# FineTuningJob(id='ftjob-AXkFLPhKr1sEk8CPo4b0Scpx', created_at=1732667439, error=Error(code=None, message=None, param=None), fine_tuned_model=None, finished_at=None, hyperparameters=Hyperparameters(n_epochs='auto', batch_size='auto', learning_rate_multiplier='auto'), model='gpt-4o-mini-2024-07-18', object='fine_tuning.job', organization_id='org-q2w5bITBqBNCRpAkDRaoYxev', result_files=[], seed=1188015549, status='validating_files', trained_tokens=None, training_file='file-JuCBbB3mgAnqQSw2XEE1GG', validation_file=None, estimated_finish=None, integrations=[], user_provided_suffix='fine-tune-qadataset-model')
